# %% [markdown]
# ----

# %% [markdown]
# ![Virus Diagram](images/virusbanner.jpg)
# # COVID-19 Data Retrieval Notebook
# #### Development Team:
# Equipo F (Cecilia Acosta, Luis Bonilla, Felipe Murillo)
# #### Date:
# May 2020
# #### Overview
# This notebook is used to gather all necessary data required to analyze COVID-19 trends:
# - World Health Organization (CSV and API):
#      - COVID-19 Cases per coungtry
#      - Hospital Beds per 10,000 ppl
# - World Bank Organization (CSV and API):
#      - Health Expenditures
#      - Income per capita
# - REST Countries (API)
#      - Collect 3 character ISO country codes for country names
#
# #### Required Inputs:
# - Data_ WHO Coronavirus Covid-19 Cases and Deaths - WHO-COVID-19-global-data.csv
# - Health_Expenditure_USDpercapita.csv
# - HealthExpenditure_%GDP.csv
# - Metadata_Country.csv
#
# #### Outputs:
# - CovidPerCountry.csv
# - Health Expenditure Master.csv
# - **Master COVID Research.csv**
# ----

# %% [markdown]
# ### Configure Dependencies

# %%
# Dependencies and Setup
import os
import pandas as pd
import numpy as np
import json
import requests

# %% [markdown]
# ----

# %% [markdown]
# ### Data Retrieval: World Health Organization (WHO) API - Number of Hospital Beds

# %%
# Create the desired URL for WHO data requests

# WHO Code corresponding to the desired metric: 
# Hospitals per 10,000 ppl
WHO_code = "WHS6_102"

# Concatenate the query URL
url = "http://apps.who.int/gho/athena/api/GHO/"+WHO_code+".json?profile=simple"

# Make JSON request to WHO API
who_data = requests.get(url).json()

# %%
# Peek JSON formatted data
print(json.dumps(who_data,indent=4, sort_keys=True))
# Out:
# {
#     "dimension": [
#         {
#             "display": "Indicator",
#             "label": "GHO"
#         },
#         {
#             "display": "PUBLISH STATES",
#             "label": "PUBLISHSTATE"
#         },
#         {
#             "display": "Year",
#             "label": "YEAR"
#         },
#         {
#             "display": "WHO region",
#             "label": "REGION"
#         },
#         {
#             "display": "Country",
#             "label": "COUNTRY"
#         }
#     ],
#     "fact": [
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "29",
#             "dim": {
#                 "COUNTRY": "Albania",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2012"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "30",
#             "dim": {
#                 "COUNTRY": "Albania",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2010"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "30",
#             "dim": {
#                 "COUNTRY": "Albania",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2009"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "33",
#             "dim": {
#                 "COUNTRY": "Albania",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2000"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "44",
#             "dim": {
#                 "COUNTRY": "Armenia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2006"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "44",
#             "dim": {
#                 "COUNTRY": "Armenia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2004"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "50",
#             "dim": {
#                 "COUNTRY": "Armenia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2001"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "77",
#             "dim": {
#                 "COUNTRY": "Austria",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2010"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "77",
#             "dim": {
#                 "COUNTRY": "Austria",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2012"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "84",
#             "dim": {
#                 "COUNTRY": "Azerbaijan",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2002"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "85",
#             "dim": {
#                 "COUNTRY": "Azerbaijan",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2001"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "29",
#             "dim": {
#                 "COUNTRY": "Bahamas",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2011"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "18",
#             "dim": {
#                 "COUNTRY": "Bahrain",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2010"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "111",
#             "dim": {
#                 "COUNTRY": "Belarus",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2008"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "111",
#             "dim": {
#                 "COUNTRY": "Belarus",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2005"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "112",
#             "dim": {
#                 "COUNTRY": "Belarus",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2007"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "126",
#             "dim": {
#                 "COUNTRY": "Belarus",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2000"
#             }
#         },
#         {
#             "Comments": "AFR GHO 22Aug2016",
#             "Value": "5",
#             "dim": {
#                 "COUNTRY": "Benin",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Africa",
#                 "YEAR": "2005"
#             }
#         },
#         {
#             "Comments": "AFR GHO 22Aug2016",
#             "Value": "5",
#             "dim": {
#                 "COUNTRY": "Benin",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Africa",
#                 "YEAR": "2010"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "11",
#             "dim": {
#                 "COUNTRY": "Bolivia (Plurinational State of)",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2009"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "11",
#             "dim": {
#                 "COUNTRY": "Bolivia (Plurinational State of)",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2012"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "32",
#             "dim": {
#                 "COUNTRY": "Bosnia and Herzegovina",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2003"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "61",
#             "dim": {
#                 "COUNTRY": "Bulgaria",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2004"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "62",
#             "dim": {
#                 "COUNTRY": "Bulgaria",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2006"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "63",
#             "dim": {
#                 "COUNTRY": "Bulgaria",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2003"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "64",
#             "dim": {
#                 "COUNTRY": "Bulgaria",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2011"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "21",
#             "dim": {
#                 "COUNTRY": "Chile",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2009"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "21",
#             "dim": {
#                 "COUNTRY": "Chile",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2011"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "22",
#             "dim": {
#                 "COUNTRY": "Chile",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2012"
#             }
#         },
#         {
#             "Comments": "WHO/OECD: Health at a Glance Asia/Pacific 2014",
#             "Value": "42",
#             "dim": {
#                 "COUNTRY": "China",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Western Pacific",
#                 "YEAR": "2012"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "60",
#             "dim": {
#                 "COUNTRY": "Croatia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2001"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "62",
#             "dim": {
#                 "COUNTRY": "Croatia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2000"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "51",
#             "dim": {
#                 "COUNTRY": "Cuba",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2013"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "53",
#             "dim": {
#                 "COUNTRY": "Cuba",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2012"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "78",
#             "dim": {
#                 "COUNTRY": "Czechia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2001"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "78",
#             "dim": {
#                 "COUNTRY": "Czechia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2002"
#             }
#         },
#         {
#             "Comments": "SEAR profiles 23Aug2016",
#             "Value": "143",
#             "dim": {
#                 "COUNTRY": "Democratic People's Republic of Korea",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "South-East Asia",
#                 "YEAR": "2010"
#             }
#         },
#         {
#             "Comments": "Eurostat",
#             "Value": "25",
#             "dim": {
#                 "COUNTRY": "Denmark",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2015"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "16",
#             "dim": {
#                 "COUNTRY": "Dominican Republic",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2014"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "17",
#             "dim": {
#                 "COUNTRY": "Dominican Republic",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2011"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "15",
#             "dim": {
#                 "COUNTRY": "Ecuador",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2007"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "15",
#             "dim": {
#                 "COUNTRY": "Ecuador",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2013"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "50",
#             "dim": {
#                 "COUNTRY": "Estonia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2013"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "52",
#             "dim": {
#                 "COUNTRY": "Estonia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2010"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "53",
#             "dim": {
#                 "COUNTRY": "Estonia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2011"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "54",
#             "dim": {
#                 "COUNTRY": "Estonia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2005"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "65",
#             "dim": {
#                 "COUNTRY": "France",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2013"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "65",
#             "dim": {
#                 "COUNTRY": "France",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2012"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "66",
#             "dim": {
#                 "COUNTRY": "France",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2011"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "69",
#             "dim": {
#                 "COUNTRY": "France",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2009"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "73",
#             "dim": {
#                 "COUNTRY": "France",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2007"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "82",
#             "dim": {
#                 "COUNTRY": "Germany",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2011"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "82",
#             "dim": {
#                 "COUNTRY": "Germany",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2007"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "82",
#             "dim": {
#                 "COUNTRY": "Germany",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2009"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "82",
#             "dim": {
#                 "COUNTRY": "Germany",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2010"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "6",
#             "dim": {
#                 "COUNTRY": "Guatemala",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2010"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "6",
#             "dim": {
#                 "COUNTRY": "Guatemala",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2011"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "6",
#             "dim": {
#                 "COUNTRY": "Guatemala",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2012"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "6",
#             "dim": {
#                 "COUNTRY": "Guatemala",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2014"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "32",
#             "dim": {
#                 "COUNTRY": "Iceland",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2014"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "32",
#             "dim": {
#                 "COUNTRY": "Iceland",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2013"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "33",
#             "dim": {
#                 "COUNTRY": "Iceland",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2012"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "36",
#             "dim": {
#                 "COUNTRY": "Iceland",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2010"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "13",
#             "dim": {
#                 "COUNTRY": "Iraq",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2011"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "13",
#             "dim": {
#                 "COUNTRY": "Iraq",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2012"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "13",
#             "dim": {
#                 "COUNTRY": "Iraq",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2013"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "13",
#             "dim": {
#                 "COUNTRY": "Iraq",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2004"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "38",
#             "dim": {
#                 "COUNTRY": "Israel",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2003"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "34",
#             "dim": {
#                 "COUNTRY": "Italy",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2012"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "35",
#             "dim": {
#                 "COUNTRY": "Italy",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2011"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "36",
#             "dim": {
#                 "COUNTRY": "Italy",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2009"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "19",
#             "dim": {
#                 "COUNTRY": "Jordan",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2007"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "67",
#             "dim": {
#                 "COUNTRY": "Kazakhstan",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2013"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "70",
#             "dim": {
#                 "COUNTRY": "Kazakhstan",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2001"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "70",
#             "dim": {
#                 "COUNTRY": "Kazakhstan",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2002"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "24",
#             "dim": {
#                 "COUNTRY": "Kuwait",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2000"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "45",
#             "dim": {
#                 "COUNTRY": "Kyrgyzstan",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2013"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "46",
#             "dim": {
#                 "COUNTRY": "Kyrgyzstan",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2012"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "48",
#             "dim": {
#                 "COUNTRY": "Kyrgyzstan",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2010"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "50",
#             "dim": {
#                 "COUNTRY": "Kyrgyzstan",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2008"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "30",
#             "dim": {
#                 "COUNTRY": "Lebanon",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2002"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "30",
#             "dim": {
#                 "COUNTRY": "Lebanon",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2003"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "30",
#             "dim": {
#                 "COUNTRY": "Lebanon",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2004"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "31",
#             "dim": {
#                 "COUNTRY": "Lebanon",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2000"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "72",
#             "dim": {
#                 "COUNTRY": "Lithuania",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2007"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "73",
#             "dim": {
#                 "COUNTRY": "Lithuania",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2013"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "73",
#             "dim": {
#                 "COUNTRY": "Lithuania",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2005"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "74",
#             "dim": {
#                 "COUNTRY": "Lithuania",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2012"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "47",
#             "dim": {
#                 "COUNTRY": "Malta",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2014"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "47",
#             "dim": {
#                 "COUNTRY": "Malta",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2012"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "48",
#             "dim": {
#                 "COUNTRY": "Malta",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2013"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "55",
#             "dim": {
#                 "COUNTRY": "Malta",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2000"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "42",
#             "dim": {
#                 "COUNTRY": "Montenegro",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2003"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "42",
#             "dim": {
#                 "COUNTRY": "Montenegro",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2000"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "43",
#             "dim": {
#                 "COUNTRY": "Montenegro",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2001"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "9",
#             "dim": {
#                 "COUNTRY": "Morocco",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2011"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "8",
#             "dim": {
#                 "COUNTRY": "Nicaragua",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2010"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "9",
#             "dim": {
#                 "COUNTRY": "Nicaragua",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2008"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "9",
#             "dim": {
#                 "COUNTRY": "Nicaragua",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2012"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "9",
#             "dim": {
#                 "COUNTRY": "Nicaragua",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2014"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "21",
#             "dim": {
#                 "COUNTRY": "Oman",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2005"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "21",
#             "dim": {
#                 "COUNTRY": "Oman",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2006"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "22",
#             "dim": {
#                 "COUNTRY": "Oman",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2000"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "6",
#             "dim": {
#                 "COUNTRY": "Pakistan",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2008"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "15",
#             "dim": {
#                 "COUNTRY": "Peru",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2013"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "16",
#             "dim": {
#                 "COUNTRY": "Peru",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2009"
#             }
#         },
#         {
#             "Comments": "WHO/OECD: Health at a Glance Asia/Pacific 2014",
#             "Value": "5",
#             "dim": {
#                 "COUNTRY": "Philippines",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Western Pacific",
#                 "YEAR": "2010"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "65",
#             "dim": {
#                 "COUNTRY": "Poland",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2006"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "65",
#             "dim": {
#                 "COUNTRY": "Poland",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2011"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "14",
#             "dim": {
#                 "COUNTRY": "Qatar",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2009"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "14",
#             "dim": {
#                 "COUNTRY": "Qatar",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2013"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "24",
#             "dim": {
#                 "COUNTRY": "Qatar",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2000"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "24",
#             "dim": {
#                 "COUNTRY": "Qatar",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2003"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "67",
#             "dim": {
#                 "COUNTRY": "Romania",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2004"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "67",
#             "dim": {
#                 "COUNTRY": "Romania",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2006"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "67",
#             "dim": {
#                 "COUNTRY": "Romania",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2003"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "77",
#             "dim": {
#                 "COUNTRY": "Romania",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2002"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "22",
#             "dim": {
#                 "COUNTRY": "Saudi Arabia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2009"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "22",
#             "dim": {
#                 "COUNTRY": "Saudi Arabia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2007"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "22",
#             "dim": {
#                 "COUNTRY": "Saudi Arabia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2010"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "22",
#             "dim": {
#                 "COUNTRY": "Saudi Arabia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2002"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "68",
#             "dim": {
#                 "COUNTRY": "Slovakia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2007"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "68",
#             "dim": {
#                 "COUNTRY": "Slovakia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2005"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "72",
#             "dim": {
#                 "COUNTRY": "Slovakia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2003"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "77",
#             "dim": {
#                 "COUNTRY": "Slovakia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2001"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "32",
#             "dim": {
#                 "COUNTRY": "Spain",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2009"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "32",
#             "dim": {
#                 "COUNTRY": "Spain",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2008"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "33",
#             "dim": {
#                 "COUNTRY": "Spain",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2006"
#             }
#         },
#         {
#             "Comments": "SEAR profiles 23Aug2016",
#             "Value": "35",
#             "dim": {
#                 "COUNTRY": "Sri Lanka",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "South-East Asia",
#                 "YEAR": "2010"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "28",
#             "dim": {
#                 "COUNTRY": "Sweden",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2009"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "28",
#             "dim": {
#                 "COUNTRY": "Sweden",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2008"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "29",
#             "dim": {
#                 "COUNTRY": "Sweden",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2006"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "47",
#             "dim": {
#                 "COUNTRY": "Switzerland",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2013"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "15",
#             "dim": {
#                 "COUNTRY": "Syrian Arab Republic",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2009"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "15",
#             "dim": {
# ...
#             "dim": {
#                 "COUNTRY": "Romania",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2008"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "95",
#             "dim": {
#                 "COUNTRY": "Russian Federation",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2007"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "97",
#             "dim": {
#                 "COUNTRY": "Russian Federation",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2005"
#             }
#         },
#         {
#             "Comments": "PAHO Regional Core Health Data",
#             "Value": "13",
#             "dim": {
#                 "COUNTRY": "Saint Lucia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Americas",
#                 "YEAR": "2013"
#             }
#         },
#         {
#             "Comments": "AFR GHO 22Aug2016",
#             "Value": "29",
#             "dim": {
#                 "COUNTRY": "Sao Tome and Principe",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Africa",
#                 "YEAR": "2011"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "21",
#             "dim": {
#                 "COUNTRY": "Saudi Arabia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2011"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "32",
#             "dim": {
#                 "COUNTRY": "Saudi Arabia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2001"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "55",
#             "dim": {
#                 "COUNTRY": "Serbia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2008"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "64",
#             "dim": {
#                 "COUNTRY": "Slovakia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2010"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "67",
#             "dim": {
#                 "COUNTRY": "Slovakia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2006"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "46",
#             "dim": {
#                 "COUNTRY": "Slovenia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2009"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "48",
#             "dim": {
#                 "COUNTRY": "Slovenia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2006"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "48",
#             "dim": {
#                 "COUNTRY": "Slovenia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2005"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "30",
#             "dim": {
#                 "COUNTRY": "Spain",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2013"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "31",
#             "dim": {
#                 "COUNTRY": "Spain",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2011"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "7",
#             "dim": {
#                 "COUNTRY": "Sudan",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2002"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "7",
#             "dim": {
#                 "COUNTRY": "Sudan",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2006"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "26",
#             "dim": {
#                 "COUNTRY": "Sweden",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2012"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "27",
#             "dim": {
#                 "COUNTRY": "Sweden",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2010"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "49",
#             "dim": {
#                 "COUNTRY": "Switzerland",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2011"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "51",
#             "dim": {
#                 "COUNTRY": "Switzerland",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2009"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "15",
#             "dim": {
#                 "COUNTRY": "Syrian Arab Republic",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2003"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "15",
#             "dim": {
#                 "COUNTRY": "Syrian Arab Republic",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2014"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "60",
#             "dim": {
#                 "COUNTRY": "Tajikistan",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2004"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "61",
#             "dim": {
#                 "COUNTRY": "Tajikistan",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2003"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "47",
#             "dim": {
#                 "COUNTRY": "Republic of North Macedonia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2005"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "48",
#             "dim": {
#                 "COUNTRY": "Republic of North Macedonia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2003"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "17",
#             "dim": {
#                 "COUNTRY": "Tunisia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2002"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "17",
#             "dim": {
#                 "COUNTRY": "Tunisia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2001"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "22",
#             "dim": {
#                 "COUNTRY": "Turkey",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2004"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "23",
#             "dim": {
#                 "COUNTRY": "Turkey",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2002"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "75",
#             "dim": {
#                 "COUNTRY": "Turkmenistan",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2011"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "77",
#             "dim": {
#                 "COUNTRY": "Turkmenistan",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2008"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "87",
#             "dim": {
#                 "COUNTRY": "Ukraine",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2004"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "88",
#             "dim": {
#                 "COUNTRY": "Ukraine",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2013"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "22",
#             "dim": {
#                 "COUNTRY": "United Arab Emirates",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2002"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "22",
#             "dim": {
#                 "COUNTRY": "United Arab Emirates",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2004"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "37",
#             "dim": {
#                 "COUNTRY": "United Kingdom of Great Britain and Northern Ireland",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2005"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "40",
#             "dim": {
#                 "COUNTRY": "United Kingdom of Great Britain and Northern Ireland",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2001"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "42",
#             "dim": {
#                 "COUNTRY": "Uzbekistan",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2012"
#             }
#         },
#         {
#             "Comments": "EURO HlthRes-DB 14Sep2016",
#             "Value": "46",
#             "dim": {
#                 "COUNTRY": "Uzbekistan",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Europe",
#                 "YEAR": "2009"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "6",
#             "dim": {
#                 "COUNTRY": "Yemen",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2000"
#             }
#         },
#         {
#             "Comments": "EMR GHO 22Aug2016",
#             "Value": "6",
#             "dim": {
#                 "COUNTRY": "Yemen",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Eastern Mediterranean",
#                 "YEAR": "2002"
#             }
#         },
#         {
#             "Comments": "AFR GHO 22Aug2016",
#             "Value": "19",
#             "dim": {
#                 "COUNTRY": "Zambia",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Africa",
#                 "YEAR": "2008"
#             }
#         },
#         {
#             "Comments": "AFR GHO 22Aug2016",
#             "Value": "30",
#             "dim": {
#                 "COUNTRY": "Zimbabwe",
#                 "GHO": "Hospital beds (per 10 000 population)",
#                 "PUBLISHSTATE": "Published",
#                 "REGION": "Africa",
#                 "YEAR": "2006"
#             }
#         }
#     ]
# }

# %%
# Determine how many countries are included in this data set
nCountries = len(who_data["fact"])

# Initialize lists
nameCountry = []       # name of country
regionCountry = []     # region country is in
bedsCountry = []       # hospital beds in country
dataYrCountry = []     # year data was sampled

# Start gathering data for all countries. 
# If a country's data can not be obtained then skip entry and move on to the next...

for country in np.arange(0,nCountries,1):
    
    try:
        nameCountry.append(who_data["fact"][country]["dim"]["COUNTRY"])
        regionCountry.append(who_data["fact"][country]["dim"]["REGION"])
        bedsCountry.append(float(who_data["fact"][country]["Value"]))
        dataYrCountry.append(int(who_data["fact"][country]["dim"]["YEAR"]))

    except:
        print(f"Country Not Listed in index {country}... skipping.")
# Out:
# Country Not Listed in index 320... skipping.

# %%
# Construct dataframe from with hospital data lists
raw_hospital_df = pd.DataFrame({"Country":nameCountry,
                                "Region":regionCountry,
                                "Hospital Beds":bedsCountry,
                                "Year Sampled":dataYrCountry})

# %%
# Create a pivot table to facilitate pulling the latest data in hospital beds for each country
grpHospital = pd.pivot_table(raw_hospital_df, values=["Hospital Beds"], index=["Country","Region"],columns=["Year Sampled"])
grpHospital["Latest Beds"] = grpHospital.ffill(axis=1).iloc[:, -1]
grpHospital.head()
# Out:
#                                           Hospital Beds                    \
# Year Sampled                                       2000  2001  2002  2003
# Country             Region
# Afghanistan         Eastern Mediterranean           3.0   4.0   4.0   4.0
# Albania             Europe                         33.0  33.0  31.0  31.0
# Algeria             Africa                          NaN   NaN   NaN   NaN
# Angola              Africa                          NaN   NaN   NaN   NaN
# Antigua and Barbuda Americas                        NaN   NaN   NaN   NaN
#
#                                                                               \
# Year Sampled                               2004  2005  2006  2007 2008  2009
# Country             Region
# Afghanistan         Eastern Mediterranean   4.0   4.0   4.0   4.0  4.0   4.0
# Albania             Europe                 30.0  31.0  31.0  31.0  NaN  30.0
# Algeria             Africa                 17.0   NaN   NaN   NaN  NaN   NaN
# Angola              Africa                  NaN   8.0   NaN   NaN  NaN   NaN
# Antigua and Barbuda Americas                NaN   NaN   NaN   NaN  NaN   NaN
#
#                                                                                \
# Year Sampled                               2010  2011  2012  2013  2014  2015
# Country             Region
# Afghanistan         Eastern Mediterranean   4.0   4.0   5.0   5.0   5.0   5.0
# Albania             Europe                 30.0  26.0  29.0  29.0   NaN   NaN
# Algeria             Africa                  NaN   NaN   NaN   NaN   NaN  19.0
# Angola              Africa                  NaN   NaN   NaN   NaN   NaN   NaN
# Antigua and Barbuda Americas               22.0  21.0   NaN  39.0  38.0   NaN
#
#                                           Latest Beds
# Year Sampled
# Country             Region
# Afghanistan         Eastern Mediterranean         5.0
# Albania             Europe                       29.0
# Algeria             Africa                       19.0
# Angola              Africa                        8.0
# Antigua and Barbuda Americas                     38.0

# %%
# Extract only the required data from the above pivot table
hospitalBedData = pd.DataFrame(grpHospital["Latest Beds"]).reset_index()
hospitalBedData.head()
# Out:
#                Country                 Region  Latest Beds
# 0          Afghanistan  Eastern Mediterranean          5.0
# 1              Albania                 Europe         29.0
# 2              Algeria                 Africa         19.0
# 3               Angola                 Africa          8.0
# 4  Antigua and Barbuda               Americas         38.0

# %% [markdown]
# ----

# %% [markdown]
# ### Data Retrieval: World Health Organization (WHO) CSV - COVID-19 DATA (dated: May 5, 2020)

# %%
# Specify CSV file containing COVID-19 data
Covid_file = os.path.join(".","inputs/Data_ WHO Coronavirus Covid-19 Cases and Deaths - WHO-COVID-19-global-data.csv")

# Import CSV file as Dataframe
Covid_df = pd.read_csv(Covid_file)
Covid_df.head()
# Out:
#    OBJECTID ISO_2_CODE ISO_3_CODE    ADM0_NAME               date_epicrv  \
# 0         1         AF        AFG  Afghanistan  2020-02-24T00:00:00.000Z
# 1         2         AF        AFG  Afghanistan  2020-02-25T00:00:00.000Z
# 2         3         AF        AFG  Afghanistan  2020-02-26T00:00:00.000Z
# 3         4         AF        AFG  Afghanistan  2020-02-27T00:00:00.000Z
# 4         5         AF        AFG  Afghanistan  2020-02-28T00:00:00.000Z
#
#    NewCase  CumCase  NewDeath  CumDeath Short_Name_ZH Short_Name_FR  \
# 0        1        1         0         0           阿富汗   Afghanistan
# 1        0        1         0         0           阿富汗   Afghanistan
# 2        0        1         0         0           阿富汗   Afghanistan
# 3        0        1         0         0           阿富汗   Afghanistan
# 4        0        1         0         0           阿富汗   Afghanistan
#
#   Short_Name_ES Short_Name_RU Short_Name_AR
# 0    Afganistán    Афганистан     أفغانستان
# 1    Afganistán    Афганистан     أفغانستان
# 2    Afganistán    Афганистан     أفغانستان
# 3    Afganistán    Афганистан     أفغانستان
# 4    Afganistán    Афганистан     أفغانستان

# %%
# Remove unnecessary columns from data frame
Covid_df = Covid_df.drop(['OBJECTID','ISO_2_CODE',
                          'Short_Name_ZH', 'Short_Name_FR',
                         'Short_Name_ES','Short_Name_RU',
                         'Short_Name_AR','NewCase',
                         'NewDeath'], axis=1)

# Rename columns to something more significant
Covid_df = Covid_df.rename(columns={"ISO_3_CODE":"Code", "ADM0_NAME":"Country",
                                   "date_epicrv":"Date"})

# Set index to "Country"
Covid_df = Covid_df.set_index("Country")

# Extract date from timestamp
Covid_df['Date'] = Covid_df['Date'].str[:10]
Covid_df.head()
# Out:
#             Code        Date  CumCase  CumDeath
# Country
# Afghanistan  AFG  2020-02-24        1         0
# Afghanistan  AFG  2020-02-25        1         0
# Afghanistan  AFG  2020-02-26        1         0
# Afghanistan  AFG  2020-02-27        1         0
# Afghanistan  AFG  2020-02-28        1         0

# %%
# Create new dataframe with the latest # of cases & deaths 
CovidMaxDeath = Covid_df.groupby(["Country","Code"])[["CumDeath"]].max()
CovidMaxCases = Covid_df.groupby(["Country","Code"])[["CumCase"]].max()
CovidPerCountry = pd.concat([CovidMaxCases,CovidMaxDeath], axis=1).reset_index()
CovidPerCountry = CovidPerCountry.set_index("Country")

# Export dataframe as a CSV
CovidPerCountry.to_csv(os.path.join(".","outputs/CovidPerCountry.csv"),index=True)
CovidPerCountry.head()
# Out:
#             Code  CumCase  CumDeath
# Country
# Afghanistan  AFG     3224        95
# Albania      ALB      803        31
# Algeria      DZA     4648       465
# Andorra      AND      751        45
# Angola       AGO       35         2

# %% [markdown]
# ----

# %% [markdown]
# ### Data Retrieval: World Bank - Health Expenditures by Country (CSV)

# %%
# Import CSV file containing "health expenditure data as percentage of GDP" into a dataframe
health_expp = pd.read_csv(os.path.join(".","inputs/HealthExpenditure_%GDP.csv"), encoding='cp1252')
health_expp.head()
# Out:
#   Country Name Country Code                         Indicator Name  \
# 0        Aruba          ABW  Current health expenditure (% of GDP)
# 1  Afghanistan          AFG  Current health expenditure (% of GDP)
# 2       Angola          AGO  Current health expenditure (% of GDP)
# 3      Albania          ALB  Current health expenditure (% of GDP)
# 4      Andorra          AND  Current health expenditure (% of GDP)
#
#       Indicator Code      2000      2001      2002      2003      2004  \
# 0  SH.XPD.CHEX.GD.ZS       NaN       NaN       NaN       NaN       NaN
# 1  SH.XPD.CHEX.GD.ZS       NaN       NaN  9.443390  8.941258  9.808473
# 2  SH.XPD.CHEX.GD.ZS  1.908599  4.483516  3.329461  3.547973  3.967201
# 3  SH.XPD.CHEX.GD.ZS       NaN       NaN       NaN       NaN       NaN
# 4  SH.XPD.CHEX.GD.ZS  9.348101  9.363031  9.119281  8.463996  8.210544
#
#        2005  ...      2010      2011       2012       2013       2014  \
# 0       NaN  ...       NaN       NaN        NaN        NaN        NaN
# 1  9.948289  ...  8.569671  8.561907   7.897176   8.805940   9.528870
# 2  2.852197  ...  2.695100  2.645608   2.395750   2.732828   2.434129
# 3       NaN  ...       NaN       NaN        NaN        NaN        NaN
# 4  8.565982  ...  9.449671  9.765894  10.046941  10.112114  10.276479
#
#         2015       2016       2017  2018  2019
# 0        NaN        NaN        NaN   NaN   NaN
# 1  10.105348  10.961983  11.777194   NaN   NaN
# 2   2.605795   2.713149   2.791500   NaN   NaN
# 3        NaN        NaN        NaN   NaN   NaN
# 4  10.252713  10.324107  10.320552   NaN   NaN
#
# [5 rows x 24 columns]

# %%
# Create a new dataframe by dropping unnecessary columns from imported dataframe
health_expp2=health_expp.drop(columns=['Indicator Name', 'Indicator Code'])

# Set dataframe index to country and country code
health_expp2=health_expp2.set_index(["Country Name","Country Code"])

# Obtain the lastest data in health expenditures
health_expp2["Latest%"]=health_expp2.ffill(axis=1).iloc[:, -1]

health_expp2.head()
# Out:
#                                2000      2001      2002      2003      2004  \
# Country Name Country Code
# Aruba        ABW                NaN       NaN       NaN       NaN       NaN
# Afghanistan  AFG                NaN       NaN  9.443390  8.941258  9.808473
# Angola       AGO           1.908599  4.483516  3.329461  3.547973  3.967201
# Albania      ALB                NaN       NaN       NaN       NaN       NaN
# Andorra      AND           9.348101  9.363031  9.119281  8.463996  8.210544
#
#                                2005       2006      2007       2008      2009  \
# Country Name Country Code
# Aruba        ABW                NaN        NaN       NaN        NaN       NaN
# Afghanistan  AFG           9.948289  10.622766  9.904674  10.256495  9.818488
# Angola       AGO           2.852197   2.685537  2.974388   3.322905  3.842609
# Albania      ALB                NaN        NaN       NaN        NaN       NaN
# Andorra      AND           8.565982   8.434281  8.428402   8.792542  9.026737
#
#                            ...      2011       2012       2013       2014  \
# Country Name Country Code  ...
# Aruba        ABW           ...       NaN        NaN        NaN        NaN
# Afghanistan  AFG           ...  8.561907   7.897176   8.805940   9.528870
# Angola       AGO           ...  2.645608   2.395750   2.732828   2.434129
# Albania      ALB           ...       NaN        NaN        NaN        NaN
# Andorra      AND           ...  9.765894  10.046941  10.112114  10.276479
#
#                                 2015       2016       2017  2018  2019  \
# Country Name Country Code
# Aruba        ABW                 NaN        NaN        NaN   NaN   NaN
# Afghanistan  AFG           10.105348  10.961983  11.777194   NaN   NaN
# Angola       AGO            2.605795   2.713149   2.791500   NaN   NaN
# Albania      ALB                 NaN        NaN        NaN   NaN   NaN
# Andorra      AND           10.252713  10.324107  10.320552   NaN   NaN
#
#                              Latest%
# Country Name Country Code
# Aruba        ABW                 NaN
# Afghanistan  AFG           11.777194
# Angola       AGO            2.791500
# Albania      ALB                 NaN
# Andorra      AND           10.320552
#
# [5 rows x 21 columns]

# %%
# Create a new dataframe containing only the latest data
health_expp3=health_expp2.reset_index()
health_expp3=health_expp3[["Country Name","Country Code","Latest%"]]
health_expp3.head()
# Out:
#   Country Name Country Code    Latest%
# 0        Aruba          ABW        NaN
# 1  Afghanistan          AFG  11.777194
# 2       Angola          AGO   2.791500
# 3      Albania          ALB        NaN
# 4      Andorra          AND  10.320552

# %%
# Read in CSV file with "health expenditure data in $USD per capita"
health_expa = pd.read_csv(os.path.join(".","inputs/Health_Expenditure_USDpercapita.csv"), encoding='cp1252')
health_expa.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name     Indicator Code  \
# 0  Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 1  Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 2  Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 3  Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 4  Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
#
#           2000         2001         2002         2003         2004  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN    16.249540    17.490738    20.927086
# 2    12.963032    28.854246    28.961367    34.718300    49.526726
# 3          NaN          NaN          NaN          NaN          NaN
# 4  2050.647461  2081.275391  2256.349121  2774.089600  3161.482178
#
#           2005  ...         2010         2011         2012         2013  \
# 0          NaN  ...          NaN          NaN          NaN          NaN
# 1    24.446512  ...    45.587749    51.553257    52.218510    55.967548
# 2    53.930702  ...    96.643700   122.117798   122.242943   143.703217
# 3          NaN  ...          NaN          NaN          NaN          NaN
# 4  3536.122803  ...  3754.731445  4013.911865  3857.161133  4107.733887
#
#           2014         2015         2016         2017  2018  2019
# 0          NaN          NaN          NaN          NaN   NaN   NaN
# 1    60.112759    60.088814    61.451286    67.122650   NaN   NaN
# 2   131.751877   108.680672    95.220802   114.459641   NaN   NaN
# 3          NaN          NaN          NaN          NaN   NaN   NaN
# 4  4346.258301  3695.067871  3843.702881  4040.786621   NaN   NaN
#
# [5 rows x 24 columns]

# %%
# Create a new dataframe by dropping unnecessary columns from imported dataframe
health_expa2=health_expa.drop(columns=['Indicator Name', 'Indicator Code'])

# Set dataframe index to country and country code
health_expa2=health_expa2.set_index(["Country Name","Country Code"])

# Obtain the lastest data in health expenditures
health_expa2["Latest$"]=health_expa2.ffill(axis=1).iloc[:, -1]
health_expa2
# Out:
#                                   2000         2001         2002         2003  \
# Country Name Country Code
# Aruba        ABW                   NaN          NaN          NaN          NaN
# Afghanistan  AFG                   NaN          NaN    16.249540    17.490738
# Angola       AGO             12.963032    28.854246    28.961367    34.718300
# Albania      ALB                   NaN          NaN          NaN          NaN
# Andorra      AND           2050.647461  2081.275391  2256.349121  2774.089600
# ...                                ...          ...          ...          ...
# Kosovo       XKX                   NaN          NaN          NaN          NaN
# Yemen, Rep.  YEM             25.154909    26.497791    27.313015    34.842796
# South Africa ZAF            221.782974   195.196320   169.022186   254.303711
# Zambia       ZMB             24.453999    24.786480    25.622341    30.856812
# Zimbabwe     ZWE                   NaN          NaN          NaN          NaN
#
#                                   2004         2005         2006         2007  \
# Country Name Country Code
# Aruba        ABW                   NaN          NaN          NaN          NaN
# Afghanistan  AFG             20.927086    24.446512    28.416662    31.840185
# Angola       AGO             49.526726    53.930702    69.424698    92.452011
# Albania      ALB                   NaN          NaN          NaN          NaN
# Andorra      AND           3161.482178  3536.122803  3689.705566  4094.544434
# ...                                ...          ...          ...          ...
# Kosovo       XKX                   NaN          NaN          NaN          NaN
# Yemen, Rep.  YEM             38.219463    42.373791    49.861038    57.953300
# South Africa ZAF            322.716400   354.062439   362.463623   386.000031
# Zambia       ZMB             37.384586    47.446941    60.508049    48.078598
# Zimbabwe     ZWE                   NaN          NaN          NaN          NaN
#
#                                   2008         2009  ...         2011  \
# Country Name Country Code                            ...
# Aruba        ABW                   NaN          NaN  ...          NaN
# Afghanistan  AFG             38.700493    42.304508  ...    51.553257
# Angola       AGO            135.208298   119.808624  ...   122.117798
# Albania      ALB                   NaN          NaN  ...          NaN
# Andorra      AND           4201.729492  3911.895996  ...  4013.911865
# ...                                ...          ...  ...          ...
# Kosovo       XKX                   NaN          NaN  ...          NaN
# Yemen, Rep.  YEM             69.357399    65.477837  ...    64.361031
# South Africa ZAF            372.355102   413.074097  ...   597.359436
# Zambia       ZMB             54.928867    50.425865  ...    56.911751
# Zimbabwe     ZWE                   NaN          NaN  ...    75.418983
#
#                                   2012         2013         2014         2015  \
# Country Name Country Code
# Aruba        ABW                   NaN          NaN          NaN          NaN
# Afghanistan  AFG             52.218510    55.967548    60.112759    60.088814
# Angola       AGO            122.242943   143.703217   131.751877   108.680672
# Albania      ALB                   NaN          NaN          NaN          NaN
# Andorra      AND           3857.161133  4107.733887  4346.258301  3695.067871
# ...                                ...          ...          ...          ...
# Kosovo       XKX                   NaN          NaN          NaN          NaN
# Yemen, Rep.  YEM             73.826073    78.390152    79.746155    72.039467
# South Africa ZAF            579.748535   526.499573   509.833221   470.796967
# Zambia       ZMB             68.191803    86.819550    66.555664    58.517654
# Zimbabwe     ZWE             75.387726    83.089012    99.553772    94.290009
#
#                                   2016         2017  2018  2019      Latest$
# Country Name Country Code
# Aruba        ABW                   NaN          NaN   NaN   NaN          NaN
# Afghanistan  AFG             61.451286    67.122650   NaN   NaN    67.122650
# Angola       AGO             95.220802   114.459641   NaN   NaN   114.459641
# Albania      ALB                   NaN          NaN   NaN   NaN          NaN
# Andorra      AND           3843.702881  4040.786621   NaN   NaN  4040.786621
# ...                                ...          ...   ...   ...          ...
# Kosovo       XKX                   NaN          NaN   NaN   NaN          NaN
# Yemen, Rep.  YEM                   NaN          NaN   NaN   NaN    72.039467
# South Africa ZAF            428.296875   499.237549   NaN   NaN   499.237549
# Zambia       ZMB             56.544182    67.648666   NaN   NaN    67.648666
# Zimbabwe     ZWE             98.579636   110.149620   NaN   NaN   110.149620
#
# [264 rows x 21 columns]

# %%
# Create a new dataframe containing only the latest data
health_expa3=health_expa2.reset_index()
health_expa3=health_expa3[["Country Name","Country Code","Latest$"]]
health_expa3.head()
# Out:
#   Country Name Country Code      Latest$
# 0        Aruba          ABW          NaN
# 1  Afghanistan          AFG    67.122650
# 2       Angola          AGO   114.459641
# 3      Albania          ALB          NaN
# 4      Andorra          AND  4040.786621

# %%
# Import CSV file grouping countries into income groups
catalogue = pd.read_csv(os.path.join(".","inputs/Metadata_Country.csv"),encoding='cp1252')
catalogue.head()
# Out:
#   Country Code                     Region          IncomeGroup SpecialNotes  \
# 0          ABW  Latin America & Caribbean          High income          NaN
# 1          AFG                 South Asia           Low income          NaN
# 2          AGO         Sub-Saharan Africa  Lower middle income          NaN
# 3          ALB      Europe & Central Asia  Upper middle income          NaN
# 4          AND      Europe & Central Asia          High income          NaN
#
#      TableName  Unnamed: 5
# 0        Aruba         NaN
# 1  Afghanistan         NaN
# 2       Angola         NaN
# 3      Albania         NaN
# 4      Andorra         NaN

# %%
# Extract columns of interest
health_exp=catalogue[["TableName","Country Code","Region","IncomeGroup"]]

# Rename column to something more significant
health_exp=health_exp.rename(columns={"TableName": "Country Name"})

health_exp.head()
# Out:
#   Country Name Country Code                     Region          IncomeGroup
# 0        Aruba          ABW  Latin America & Caribbean          High income
# 1  Afghanistan          AFG                 South Asia           Low income
# 2       Angola          AGO         Sub-Saharan Africa  Lower middle income
# 3      Albania          ALB      Europe & Central Asia  Upper middle income
# 4      Andorra          AND      Europe & Central Asia          High income

# %%
# Merge income group data into "health expenditure data in $USD per capita" dataframe
health_expfull=pd.merge(health_exp, health_expa3, on="Country Name", how="left")

health_expfull.head()
# Out:
#   Country Name Country Code_x                     Region          IncomeGroup  \
# 0        Aruba            ABW  Latin America & Caribbean          High income
# 1  Afghanistan            AFG                 South Asia           Low income
# 2       Angola            AGO         Sub-Saharan Africa  Lower middle income
# 3      Albania            ALB      Europe & Central Asia  Upper middle income
# 4      Andorra            AND      Europe & Central Asia          High income
#
#   Country Code_y      Latest$
# 0            ABW          NaN
# 1            AFG    67.122650
# 2            AGO   114.459641
# 3            ALB          NaN
# 4            AND  4040.786621

# %%
# Merge "health expenditure data as percentage of GDP" to create complete helath expenditure dataframe
health_expfull=pd.merge(health_expfull, health_expp3, on="Country Name", how="left")
health_expfull.head()
# Out:
#   Country Name Country Code_x                     Region          IncomeGroup  \
# 0        Aruba            ABW  Latin America & Caribbean          High income
# 1  Afghanistan            AFG                 South Asia           Low income
# 2       Angola            AGO         Sub-Saharan Africa  Lower middle income
# 3      Albania            ALB      Europe & Central Asia  Upper middle income
# 4      Andorra            AND      Europe & Central Asia          High income
#
#   Country Code_y      Latest$ Country Code    Latest%
# 0            ABW          NaN          ABW        NaN
# 1            AFG    67.122650          AFG  11.777194
# 2            AGO   114.459641          AGO   2.791500
# 3            ALB          NaN          ALB        NaN
# 4            AND  4040.786621          AND  10.320552

# %%
# Remove duplicated columns
health_expfull=health_expfull.drop(columns=["Country Code_y","Country Code"])

# Rename columns
health_expfull=health_expfull.rename(
    columns={"Country Name": "Country",
            "Country Code_x": "Code",
            "Latest$":"Health Expenditure per capita (current USD)",
            "Latest%":"Health Expenditure (% of GDP)"
            })
health_expfull
# Out:
#           Country Code                      Region          IncomeGroup  \
# 0           Aruba  ABW   Latin America & Caribbean          High income
# 1     Afghanistan  AFG                  South Asia           Low income
# 2          Angola  AGO          Sub-Saharan Africa  Lower middle income
# 3         Albania  ALB       Europe & Central Asia  Upper middle income
# 4         Andorra  AND       Europe & Central Asia          High income
# ..            ...  ...                         ...                  ...
# 258        Kosovo  XKX       Europe & Central Asia  Upper middle income
# 259   Yemen, Rep.  YEM  Middle East & North Africa           Low income
# 260  South Africa  ZAF          Sub-Saharan Africa  Upper middle income
# 261        Zambia  ZMB          Sub-Saharan Africa  Lower middle income
# 262      Zimbabwe  ZWE          Sub-Saharan Africa  Lower middle income
#
#      Health Expenditure per capita (current USD)  \
# 0                                            NaN
# 1                                      67.122650
# 2                                     114.459641
# 3                                            NaN
# 4                                    4040.786621
# ..                                           ...
# 258                                          NaN
# 259                                    72.039467
# 260                                   499.237549
# 261                                    67.648666
# 262                                   110.149620
#
#      Health Expenditure (% of GDP)
# 0                              NaN
# 1                        11.777194
# 2                         2.791500
# 3                              NaN
# 4                        10.320552
# ..                             ...
# 258                            NaN
# 259                       4.234575
# 260                       8.113118
# 261                       4.470341
# 262                       6.635916
#
# [263 rows x 6 columns]

# %%
# Export master dataframe containing all health expenditures as a CSV for future use
health_expfull.to_csv(os.path.join(".","outputs/Health Expenditure Master.csv"))

# %% [markdown]
# ----

# %% [markdown]
# ### Pre-Data Retrieval API: Obtaining ISO codes for Countries

# %%
# Before making country specific requests, need a mapping of country name to iso2code (used by World Bank to make
# individual country requests)

# World Bank iso3code listing for all countries
code_url = "https://restcountries.eu/rest/v2/all"

# Make JSON request to Rest Countries API
country_data = requests.get(code_url).json()

# Peek JSON formatted data
print(json.dumps(country_data,indent=4, sort_keys=True))
# Out:
# [
#     {
#         "alpha2Code": "AF",
#         "alpha3Code": "AFG",
#         "altSpellings": [
#             "AF",
#             "Af\u0121\u0101nist\u0101n"
#         ],
#         "area": 652230.0,
#         "borders": [
#             "IRN",
#             "PAK",
#             "TKM",
#             "UZB",
#             "TJK",
#             "CHN"
#         ],
#         "callingCodes": [
#             "93"
#         ],
#         "capital": "Kabul",
#         "cioc": "AFG",
#         "currencies": [
#             {
#                 "code": "AFN",
#                 "name": "Afghan afghani",
#                 "symbol": "\u060b"
#             }
#         ],
#         "demonym": "Afghan",
#         "flag": "https://restcountries.eu/data/afg.svg",
#         "gini": 27.8,
#         "languages": [
#             {
#                 "iso639_1": "ps",
#                 "iso639_2": "pus",
#                 "name": "Pashto",
#                 "nativeName": "\u067e\u069a\u062a\u0648"
#             },
#             {
#                 "iso639_1": "uz",
#                 "iso639_2": "uzb",
#                 "name": "Uzbek",
#                 "nativeName": "O\u02bbzbek"
#             },
#             {
#                 "iso639_1": "tk",
#                 "iso639_2": "tuk",
#                 "name": "Turkmen",
#                 "nativeName": "T\u00fcrkmen"
#             }
#         ],
#         "latlng": [
#             33.0,
#             65.0
#         ],
#         "name": "Afghanistan",
#         "nativeName": "\u0627\u0641\u063a\u0627\u0646\u0633\u062a\u0627\u0646",
#         "numericCode": "004",
#         "population": 27657145,
#         "region": "Asia",
#         "regionalBlocs": [
#             {
#                 "acronym": "SAARC",
#                 "name": "South Asian Association for Regional Cooperation",
#                 "otherAcronyms": [],
#                 "otherNames": []
#             }
#         ],
#         "subregion": "Southern Asia",
#         "timezones": [
#             "UTC+04:30"
#         ],
#         "topLevelDomain": [
#             ".af"
#         ],
#         "translations": {
#             "br": "Afeganist\u00e3o",
#             "de": "Afghanistan",
#             "es": "Afganist\u00e1n",
#             "fa": "\u0627\u0641\u063a\u0627\u0646\u0633\u062a\u0627\u0646",
#             "fr": "Afghanistan",
#             "hr": "Afganistan",
#             "it": "Afghanistan",
#             "ja": "\u30a2\u30d5\u30ac\u30cb\u30b9\u30bf\u30f3",
#             "nl": "Afghanistan",
#             "pt": "Afeganist\u00e3o"
#         }
#     },
#     {
#         "alpha2Code": "AX",
#         "alpha3Code": "ALA",
#         "altSpellings": [
#             "AX",
#             "Aaland",
#             "Aland",
#             "Ahvenanmaa"
#         ],
#         "area": 1580.0,
#         "borders": [],
#         "callingCodes": [
#             "358"
#         ],
#         "capital": "Mariehamn",
#         "cioc": "",
#         "currencies": [
#             {
#                 "code": "EUR",
#                 "name": "Euro",
#                 "symbol": "\u20ac"
#             }
#         ],
#         "demonym": "\u00c5landish",
#         "flag": "https://restcountries.eu/data/ala.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "sv",
#                 "iso639_2": "swe",
#                 "name": "Swedish",
#                 "nativeName": "svenska"
#             }
#         ],
#         "latlng": [
#             60.116667,
#             19.9
#         ],
#         "name": "\u00c5land Islands",
#         "nativeName": "\u00c5land",
#         "numericCode": "248",
#         "population": 28875,
#         "region": "Europe",
#         "regionalBlocs": [
#             {
#                 "acronym": "EU",
#                 "name": "European Union",
#                 "otherAcronyms": [],
#                 "otherNames": []
#             }
#         ],
#         "subregion": "Northern Europe",
#         "timezones": [
#             "UTC+02:00"
#         ],
#         "topLevelDomain": [
#             ".ax"
#         ],
#         "translations": {
#             "br": "Ilhas de Aland",
#             "de": "\u00c5land",
#             "es": "Alandia",
#             "fa": "\u062c\u0632\u0627\u06cc\u0631 \u0627\u0644\u0646\u062f",
#             "fr": "\u00c5land",
#             "hr": "\u00c5landski otoci",
#             "it": "Isole Aland",
#             "ja": "\u30aa\u30fc\u30e9\u30f3\u30c9\u8af8\u5cf6",
#             "nl": "\u00c5landeilanden",
#             "pt": "Ilhas de Aland"
#         }
#     },
#     {
#         "alpha2Code": "AL",
#         "alpha3Code": "ALB",
#         "altSpellings": [
#             "AL",
#             "Shqip\u00ebri",
#             "Shqip\u00ebria",
#             "Shqipnia"
#         ],
#         "area": 28748.0,
#         "borders": [
#             "MNE",
#             "GRC",
#             "MKD",
#             "KOS"
#         ],
#         "callingCodes": [
#             "355"
#         ],
#         "capital": "Tirana",
#         "cioc": "ALB",
#         "currencies": [
#             {
#                 "code": "ALL",
#                 "name": "Albanian lek",
#                 "symbol": "L"
#             }
#         ],
#         "demonym": "Albanian",
#         "flag": "https://restcountries.eu/data/alb.svg",
#         "gini": 34.5,
#         "languages": [
#             {
#                 "iso639_1": "sq",
#                 "iso639_2": "sqi",
#                 "name": "Albanian",
#                 "nativeName": "Shqip"
#             }
#         ],
#         "latlng": [
#             41.0,
#             20.0
#         ],
#         "name": "Albania",
#         "nativeName": "Shqip\u00ebria",
#         "numericCode": "008",
#         "population": 2886026,
#         "region": "Europe",
#         "regionalBlocs": [
#             {
#                 "acronym": "CEFTA",
#                 "name": "Central European Free Trade Agreement",
#                 "otherAcronyms": [],
#                 "otherNames": []
#             }
#         ],
#         "subregion": "Southern Europe",
#         "timezones": [
#             "UTC+01:00"
#         ],
#         "topLevelDomain": [
#             ".al"
#         ],
#         "translations": {
#             "br": "Alb\u00e2nia",
#             "de": "Albanien",
#             "es": "Albania",
#             "fa": "\u0622\u0644\u0628\u0627\u0646\u06cc",
#             "fr": "Albanie",
#             "hr": "Albanija",
#             "it": "Albania",
#             "ja": "\u30a2\u30eb\u30d0\u30cb\u30a2",
#             "nl": "Albani\u00eb",
#             "pt": "Alb\u00e2nia"
#         }
#     },
#     {
#         "alpha2Code": "DZ",
#         "alpha3Code": "DZA",
#         "altSpellings": [
#             "DZ",
#             "Dzayer",
#             "Alg\u00e9rie"
#         ],
#         "area": 2381741.0,
#         "borders": [
#             "TUN",
#             "LBY",
#             "NER",
#             "ESH",
#             "MRT",
#             "MLI",
#             "MAR"
#         ],
#         "callingCodes": [
#             "213"
#         ],
#         "capital": "Algiers",
#         "cioc": "ALG",
#         "currencies": [
#             {
#                 "code": "DZD",
#                 "name": "Algerian dinar",
#                 "symbol": "\u062f.\u062c"
#             }
#         ],
#         "demonym": "Algerian",
#         "flag": "https://restcountries.eu/data/dza.svg",
#         "gini": 35.3,
#         "languages": [
#             {
#                 "iso639_1": "ar",
#                 "iso639_2": "ara",
#                 "name": "Arabic",
#                 "nativeName": "\u0627\u0644\u0639\u0631\u0628\u064a\u0629"
#             }
#         ],
#         "latlng": [
#             28.0,
#             3.0
#         ],
#         "name": "Algeria",
#         "nativeName": "\u0627\u0644\u062c\u0632\u0627\u0626\u0631",
#         "numericCode": "012",
#         "population": 40400000,
#         "region": "Africa",
#         "regionalBlocs": [
#             {
#                 "acronym": "AU",
#                 "name": "African Union",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "\u0627\u0644\u0627\u062a\u062d\u0627\u062f \u0627\u0644\u0623\u0641\u0631\u064a\u0642\u064a",
#                     "Union africaine",
#                     "Uni\u00e3o Africana",
#                     "Uni\u00f3n Africana",
#                     "Umoja wa Afrika"
#                 ]
#             },
#             {
#                 "acronym": "AL",
#                 "name": "Arab League",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "\u062c\u0627\u0645\u0639\u0629 \u0627\u0644\u062f\u0648\u0644 \u0627\u0644\u0639\u0631\u0628\u064a\u0629",
#                     "J\u0101mi\u02bbat ad-Duwal al-\u02bbArab\u012byah",
#                     "League of Arab States"
#                 ]
#             }
#         ],
#         "subregion": "Northern Africa",
#         "timezones": [
#             "UTC+01:00"
#         ],
#         "topLevelDomain": [
#             ".dz"
#         ],
#         "translations": {
#             "br": "Arg\u00e9lia",
#             "de": "Algerien",
#             "es": "Argelia",
#             "fa": "\u0627\u0644\u062c\u0632\u0627\u06cc\u0631",
#             "fr": "Alg\u00e9rie",
#             "hr": "Al\u017eir",
#             "it": "Algeria",
#             "ja": "\u30a2\u30eb\u30b8\u30a7\u30ea\u30a2",
#             "nl": "Algerije",
#             "pt": "Arg\u00e9lia"
#         }
#     },
#     {
#         "alpha2Code": "AS",
#         "alpha3Code": "ASM",
#         "altSpellings": [
#             "AS",
#             "Amerika S\u0101moa",
#             "Amelika S\u0101moa",
#             "S\u0101moa Amelika"
#         ],
#         "area": 199.0,
#         "borders": [],
#         "callingCodes": [
#             "1684"
#         ],
#         "capital": "Pago Pago",
#         "cioc": "ASA",
#         "currencies": [
#             {
#                 "code": "USD",
#                 "name": "United State Dollar",
#                 "symbol": "$"
#             }
#         ],
#         "demonym": "American Samoan",
#         "flag": "https://restcountries.eu/data/asm.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "en",
#                 "iso639_2": "eng",
#                 "name": "English",
#                 "nativeName": "English"
#             },
#             {
#                 "iso639_1": "sm",
#                 "iso639_2": "smo",
#                 "name": "Samoan",
#                 "nativeName": "gagana fa'a Samoa"
#             }
#         ],
#         "latlng": [
#             -14.33333333,
#             -170.0
#         ],
#         "name": "American Samoa",
#         "nativeName": "American Samoa",
#         "numericCode": "016",
#         "population": 57100,
#         "region": "Oceania",
#         "regionalBlocs": [],
#         "subregion": "Polynesia",
#         "timezones": [
#             "UTC-11:00"
#         ],
#         "topLevelDomain": [
#             ".as"
#         ],
#         "translations": {
#             "br": "Samoa Americana",
#             "de": "Amerikanisch-Samoa",
#             "es": "Samoa Americana",
#             "fa": "\u0633\u0627\u0645\u0648\u0622\u06cc \u0622\u0645\u0631\u06cc\u06a9\u0627",
#             "fr": "Samoa am\u00e9ricaines",
#             "hr": "Ameri\u010dka Samoa",
#             "it": "Samoa Americane",
#             "ja": "\u30a2\u30e1\u30ea\u30ab\u9818\u30b5\u30e2\u30a2",
#             "nl": "Amerikaans Samoa",
#             "pt": "Samoa Americana"
#         }
#     },
#     {
#         "alpha2Code": "AD",
#         "alpha3Code": "AND",
#         "altSpellings": [
#             "AD",
#             "Principality of Andorra",
#             "Principat d'Andorra"
#         ],
#         "area": 468.0,
#         "borders": [
#             "FRA",
#             "ESP"
#         ],
#         "callingCodes": [
#             "376"
#         ],
#         "capital": "Andorra la Vella",
#         "cioc": "AND",
#         "currencies": [
#             {
#                 "code": "EUR",
#                 "name": "Euro",
#                 "symbol": "\u20ac"
#             }
#         ],
#         "demonym": "Andorran",
#         "flag": "https://restcountries.eu/data/and.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "ca",
#                 "iso639_2": "cat",
#                 "name": "Catalan",
#                 "nativeName": "catal\u00e0"
#             }
#         ],
#         "latlng": [
#             42.5,
#             1.5
#         ],
#         "name": "Andorra",
#         "nativeName": "Andorra",
#         "numericCode": "020",
#         "population": 78014,
#         "region": "Europe",
#         "regionalBlocs": [],
#         "subregion": "Southern Europe",
#         "timezones": [
#             "UTC+01:00"
#         ],
#         "topLevelDomain": [
#             ".ad"
#         ],
#         "translations": {
#             "br": "Andorra",
#             "de": "Andorra",
#             "es": "Andorra",
#             "fa": "\u0622\u0646\u062f\u0648\u0631\u0627",
#             "fr": "Andorre",
#             "hr": "Andora",
#             "it": "Andorra",
#             "ja": "\u30a2\u30f3\u30c9\u30e9",
#             "nl": "Andorra",
#             "pt": "Andorra"
#         }
#     },
#     {
#         "alpha2Code": "AO",
#         "alpha3Code": "AGO",
#         "altSpellings": [
#             "AO",
#             "Rep\u00fablica de Angola",
#             "\u0281\u025bpublika de an'\u0261\u0254la"
#         ],
#         "area": 1246700.0,
#         "borders": [
#             "COG",
#             "COD",
#             "ZMB",
#             "NAM"
#         ],
#         "callingCodes": [
#             "244"
#         ],
#         "capital": "Luanda",
#         "cioc": "ANG",
#         "currencies": [
#             {
#                 "code": "AOA",
#                 "name": "Angolan kwanza",
#                 "symbol": "Kz"
#             }
#         ],
#         "demonym": "Angolan",
#         "flag": "https://restcountries.eu/data/ago.svg",
#         "gini": 58.6,
#         "languages": [
#             {
#                 "iso639_1": "pt",
#                 "iso639_2": "por",
#                 "name": "Portuguese",
#                 "nativeName": "Portugu\u00eas"
#             }
#         ],
#         "latlng": [
#             -12.5,
#             18.5
#         ],
#         "name": "Angola",
#         "nativeName": "Angola",
#         "numericCode": "024",
#         "population": 25868000,
#         "region": "Africa",
#         "regionalBlocs": [
#             {
#                 "acronym": "AU",
#                 "name": "African Union",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "\u0627\u0644\u0627\u062a\u062d\u0627\u062f \u0627\u0644\u0623\u0641\u0631\u064a\u0642\u064a",
#                     "Union africaine",
#                     "Uni\u00e3o Africana",
#                     "Uni\u00f3n Africana",
#                     "Umoja wa Afrika"
#                 ]
#             }
#         ],
#         "subregion": "Middle Africa",
#         "timezones": [
#             "UTC+01:00"
#         ],
#         "topLevelDomain": [
#             ".ao"
#         ],
#         "translations": {
#             "br": "Angola",
#             "de": "Angola",
#             "es": "Angola",
#             "fa": "\u0622\u0646\u06af\u0648\u0644\u0627",
#             "fr": "Angola",
#             "hr": "Angola",
#             "it": "Angola",
#             "ja": "\u30a2\u30f3\u30b4\u30e9",
#             "nl": "Angola",
#             "pt": "Angola"
#         }
#     },
#     {
#         "alpha2Code": "AI",
#         "alpha3Code": "AIA",
#         "altSpellings": [
#             "AI"
#         ],
#         "area": 91.0,
#         "borders": [],
#         "callingCodes": [
#             "1264"
#         ],
#         "capital": "The Valley",
#         "cioc": "",
#         "currencies": [
#             {
#                 "code": "XCD",
#                 "name": "East Caribbean dollar",
#                 "symbol": "$"
#             }
#         ],
#         "demonym": "Anguillian",
#         "flag": "https://restcountries.eu/data/aia.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "en",
#                 "iso639_2": "eng",
#                 "name": "English",
#                 "nativeName": "English"
#             }
#         ],
#         "latlng": [
#             18.25,
#             -63.16666666
#         ],
#         "name": "Anguilla",
#         "nativeName": "Anguilla",
#         "numericCode": "660",
#         "population": 13452,
#         "region": "Americas",
#         "regionalBlocs": [],
#         "subregion": "Caribbean",
#         "timezones": [
#             "UTC-04:00"
#         ],
#         "topLevelDomain": [
#             ".ai"
#         ],
#         "translations": {
#             "br": "Anguila",
#             "de": "Anguilla",
#             "es": "Anguilla",
#             "fa": "\u0622\u0646\u06af\u0648\u06cc\u0644\u0627",
#             "fr": "Anguilla",
#             "hr": "Angvila",
#             "it": "Anguilla",
#             "ja": "\u30a2\u30f3\u30ae\u30e9",
#             "nl": "Anguilla",
#             "pt": "Anguila"
#         }
#     },
#     {
#         "alpha2Code": "AQ",
#         "alpha3Code": "ATA",
#         "altSpellings": [],
#         "area": 14000000.0,
#         "borders": [],
#         "callingCodes": [
#             "672"
#         ],
#         "capital": "",
#         "cioc": "",
#         "currencies": [
#             {
#                 "code": "AUD",
#                 "name": "Australian dollar",
#                 "symbol": "$"
#             },
#             {
#                 "code": "GBP",
#                 "name": "British pound",
#                 "symbol": "\u00a3"
#             }
#         ],
#         "demonym": "",
#         "flag": "https://restcountries.eu/data/ata.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "en",
#                 "iso639_2": "eng",
#                 "name": "English",
#                 "nativeName": "English"
#             },
#             {
#                 "iso639_1": "ru",
#                 "iso639_2": "rus",
#                 "name": "Russian",
#                 "nativeName": "\u0420\u0443\u0441\u0441\u043a\u0438\u0439"
#             }
#         ],
#         "latlng": [
#             -74.65,
#             4.48
#         ],
#         "name": "Antarctica",
#         "nativeName": "Antarctica",
#         "numericCode": "010",
#         "population": 1000,
#         "region": "Polar",
#         "regionalBlocs": [],
#         "subregion": "",
#         "timezones": [
#             "UTC-03:00",
#             "UTC+03:00",
#             "UTC+05:00",
#             "UTC+06:00",
#             "UTC+07:00",
#             "UTC+08:00",
#             "UTC+10:00",
#             "UTC+12:00"
#         ],
#         "topLevelDomain": [
#             ".aq"
#         ],
#         "translations": {
#             "br": "Ant\u00e1rtida",
#             "de": "Antarktika",
#             "es": "Ant\u00e1rtida",
#             "fa": "\u062c\u0646\u0648\u0628\u06af\u0627\u0646",
#             "fr": "Antarctique",
#             "hr": "Antarktika",
#             "it": "Antartide",
#             "ja": "\u5357\u6975\u5927\u9678",
#             "nl": "Antarctica",
#             "pt": "Ant\u00e1rctida"
#         }
#     },
#     {
#         "alpha2Code": "AG",
#         "alpha3Code": "ATG",
#         "altSpellings": [
#             "AG"
#         ],
#         "area": 442.0,
#         "borders": [],
#         "callingCodes": [
#             "1268"
#         ],
#         "capital": "Saint John's",
#         "cioc": "ANT",
#         "currencies": [
#             {
#                 "code": "XCD",
#                 "name": "East Caribbean dollar",
#                 "symbol": "$"
#             }
#         ],
#         "demonym": "Antiguan, Barbudan",
#         "flag": "https://restcountries.eu/data/atg.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "en",
#                 "iso639_2": "eng",
#                 "name": "English",
#                 "nativeName": "English"
#             }
#         ],
#         "latlng": [
#             17.05,
#             -61.8
#         ],
#         "name": "Antigua and Barbuda",
#         "nativeName": "Antigua and Barbuda",
#         "numericCode": "028",
#         "population": 86295,
#         "region": "Americas",
#         "regionalBlocs": [
#             {
#                 "acronym": "CARICOM",
#                 "name": "Caribbean Community",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "Comunidad del Caribe",
#                     "Communaut\u00e9 Carib\u00e9enne",
#                     "Caribische Gemeenschap"
#                 ]
#             }
#         ],
#         "subregion": "Caribbean",
#         "timezones": [
#             "UTC-04:00"
#         ],
#         "topLevelDomain": [
#             ".ag"
#         ],
#         "translations": {
#             "br": "Ant\u00edgua e Barbuda",
#             "de": "Antigua und Barbuda",
#             "es": "Antigua y Barbuda",
#             "fa": "\u0622\u0646\u062a\u06cc\u06af\u0648\u0627 \u0648 \u0628\u0627\u0631\u0628\u0648\u062f\u0627",
#             "fr": "Antigua-et-Barbuda",
#             "hr": "Antigva i Barbuda",
#             "it": "Antigua e Barbuda",
#             "ja": "\u30a2\u30f3\u30c6\u30a3\u30b0\u30a2\u30fb\u30d0\u30fc\u30d6\u30fc\u30c0",
#             "nl": "Antigua en Barbuda",
#             "pt": "Ant\u00edgua e Barbuda"
#         }
#     },
#     {
#         "alpha2Code": "AR",
#         "alpha3Code": "ARG",
#         "altSpellings": [
#             "AR",
#             "Argentine Republic",
#             "Rep\u00fablica Argentina"
#         ],
#         "area": 2780400.0,
#         "borders": [
#             "BOL",
#             "BRA",
#             "CHL",
#             "PRY",
#             "URY"
#         ],
#         "callingCodes": [
#             "54"
#         ],
#         "capital": "Buenos Aires",
#         "cioc": "ARG",
#         "currencies": [
#             {
#                 "code": "ARS",
#                 "name": "Argentine peso",
#                 "symbol": "$"
#             }
#         ],
#         "demonym": "Argentinean",
#         "flag": "https://restcountries.eu/data/arg.svg",
#         "gini": 44.5,
#         "languages": [
#             {
#                 "iso639_1": "es",
#                 "iso639_2": "spa",
#                 "name": "Spanish",
#                 "nativeName": "Espa\u00f1ol"
#             },
#             {
#                 "iso639_1": "gn",
#                 "iso639_2": "grn",
#                 "name": "Guaran\u00ed",
#                 "nativeName": "Ava\u00f1e'\u1ebd"
#             }
#         ],
#         "latlng": [
#             -34.0,
#             -64.0
#         ],
#         "name": "Argentina",
#         "nativeName": "Argentina",
#         "numericCode": "032",
#         "population": 43590400,
#         "region": "Americas",
#         "regionalBlocs": [
#             {
#                 "acronym": "USAN",
#                 "name": "Union of South American Nations",
#                 "otherAcronyms": [
#                     "UNASUR",
#                     "UNASUL",
#                     "UZAN"
#                 ],
#                 "otherNames": [
#                     "Uni\u00f3n de Naciones Suramericanas",
#                     "Uni\u00e3o de Na\u00e7\u00f5es Sul-Americanas",
#                     "Unie van Zuid-Amerikaanse Naties",
#                     "South American Union"
#                 ]
#             }
#         ],
#         "subregion": "South America",
#         "timezones": [
#             "UTC-03:00"
#         ],
#         "topLevelDomain": [
#             ".ar"
#         ],
#         "translations": {
#             "br": "Argentina",
#             "de": "Argentinien",
#             "es": "Argentina",
#             "fa": "\u0622\u0631\u0698\u0627\u0646\u062a\u06cc\u0646",
#             "fr": "Argentine",
#             "hr": "Argentina",
#             "it": "Argentina",
#             "ja": "\u30a2\u30eb\u30bc\u30f3\u30c1\u30f3",
#             "nl": "Argentini\u00eb",
#             "pt": "Argentina"
#         }
#     },
#     {
#         "alpha2Code": "AM",
#         "alpha3Code": "ARM",
#         "altSpellings": [
#             "AM",
#             "Hayastan",
#             "Republic of Armenia",
#             "\u0540\u0561\u0575\u0561\u057d\u057f\u0561\u0576\u056b \u0540\u0561\u0576\u0580\u0561\u057a\u0565\u057f\u0578\u0582\u0569\u0575\u0578\u0582\u0576"
#         ],
#         "area": 29743.0,
#         "borders": [
#             "AZE",
#             "GEO",
#             "IRN",
#             "TUR"
#         ],
#         "callingCodes": [
#             "374"
#         ],
#         "capital": "Yerevan",
#         "cioc": "ARM",
#         "currencies": [
#             {
#                 "code": "AMD",
#                 "name": "Armenian dram",
#                 "symbol": null
#             }
#         ],
#         "demonym": "Armenian",
#         "flag": "https://restcountries.eu/data/arm.svg",
#         "gini": 30.9,
#         "languages": [
#             {
#                 "iso639_1": "hy",
#                 "iso639_2": "hye",
#                 "name": "Armenian",
#                 "nativeName": "\u0540\u0561\u0575\u0565\u0580\u0565\u0576"
#             },
#             {
#                 "iso639_1": "ru",
#                 "iso639_2": "rus",
#                 "name": "Russian",
#                 "nativeName": "\u0420\u0443\u0441\u0441\u043a\u0438\u0439"
#             }
#         ],
#         "latlng": [
#             40.0,
#             45.0
#         ],
#         "name": "Armenia",
#         "nativeName": "\u0540\u0561\u0575\u0561\u057d\u057f\u0561\u0576",
#         "numericCode": "051",
#         "population": 2994400,
#         "region": "Asia",
#         "regionalBlocs": [
#             {
#                 "acronym": "EEU",
#                 "name": "Eurasian Economic Union",
#                 "otherAcronyms": [
#                     "EAEU"
#                 ],
#                 "otherNames": []
#             }
#         ],
#         "subregion": "Western Asia",
#         "timezones": [
#             "UTC+04:00"
#         ],
#         "topLevelDomain": [
#             ".am"
#         ],
#         "translations": {
#             "br": "Arm\u00eania",
#             "de": "Armenien",
#             "es": "Armenia",
#             "fa": "\u0627\u0631\u0645\u0646\u0633\u062a\u0627\u0646",
#             "fr": "Arm\u00e9nie",
#             "hr": "Armenija",
#             "it": "Armenia",
#             "ja": "\u30a2\u30eb\u30e1\u30cb\u30a2",
#             "nl": "Armeni\u00eb",
#             "pt": "Arm\u00e9nia"
#         }
#     },
#     {
#         "alpha2Code": "AW",
#         "alpha3Code": "ABW",
#         "altSpellings": [
#             "AW"
#         ],
#         "area": 180.0,
#         "borders": [],
#         "callingCodes": [
#             "297"
#         ],
#         "capital": "Oranjestad",
#         "cioc": "ARU",
#         "currencies": [
#             {
#                 "code": "AWG",
#                 "name": "Aruban florin",
#                 "symbol": "\u0192"
#             }
#         ],
#         "demonym": "Aruban",
#         "flag": "https://restcountries.eu/data/abw.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "nl",
#                 "iso639_2": "nld",
#                 "name": "Dutch",
#                 "nativeName": "Nederlands"
#             },
#             {
#                 "iso639_1": "pa",
#                 "iso639_2": "pan",
#                 "name": "(Eastern) Punjabi",
#                 "nativeName": "\u0a2a\u0a70\u0a1c\u0a3e\u0a2c\u0a40"
#             }
#         ],
#         "latlng": [
#             12.5,
#             -69.96666666
#         ],
#         "name": "Aruba",
#         "nativeName": "Aruba",
#         "numericCode": "533",
#         "population": 107394,
#         "region": "Americas",
#         "regionalBlocs": [],
#         "subregion": "Caribbean",
#         "timezones": [
#             "UTC-04:00"
#         ],
#         "topLevelDomain": [
#             ".aw"
#         ],
#         "translations": {
#             "br": "Aruba",
#             "de": "Aruba",
#             "es": "Aruba",
#             "fa": "\u0622\u0631\u0648\u0628\u0627",
#             "fr": "Aruba",
#             "hr": "Aruba",
#             "it": "Aruba",
#             "ja": "\u30a2\u30eb\u30d0",
#             "nl": "Aruba",
#             "pt": "Aruba"
#         }
#     },
#     {
#         "alpha2Code": "AU",
#         "alpha3Code": "AUS",
#         "altSpellings": [
#             "AU"
#         ],
#         "area": 7692024.0,
#         "borders": [],
#         "callingCodes": [
#             "61"
#         ],
#         "capital": "Canberra",
#         "cioc": "AUS",
#         "currencies": [
#             {
#                 "code": "AUD",
#                 "name": "Australian dollar",
#                 "symbol": "$"
#             }
#         ],
#         "demonym": "Australian",
#         "flag": "https://restcountries.eu/data/aus.svg",
#         "gini": 30.5,
#         "languages": [
#             {
#                 "iso639_1": "en",
#                 "iso639_2": "eng",
#                 "name": "English",
#                 "nativeName": "English"
#             }
#         ],
#         "latlng": [
#             -27.0,
#             133.0
#         ],
#         "name": "Australia",
#         "nativeName": "Australia",
#         "numericCode": "036",
#         "population": 24117360,
#         "region": "Oceania",
#         "regionalBlocs": [],
#         "subregion": "Australia and New Zealand",
#         "timezones": [
#             "UTC+05:00",
#             "UTC+06:30",
#             "UTC+07:00",
#             "UTC+08:00",
#             "UTC+09:30",
#             "UTC+10:00",
#             "UTC+10:30",
#             "UTC+11:30"
#         ],
#         "topLevelDomain": [
#             ".au"
#         ],
#         "translations": {
#             "br": "Austr\u00e1lia",
#             "de": "Australien",
#             "es": "Australia",
#             "fa": "\u0627\u0633\u062a\u0631\u0627\u0644\u06cc\u0627",
#             "fr": "Australie",
#             "hr": "Australija",
#             "it": "Australia",
#             "ja": "\u30aa\u30fc\u30b9\u30c8\u30e9\u30ea\u30a2",
#             "nl": "Australi\u00eb",
#             "pt": "Austr\u00e1lia"
#         }
#     },
#     {
#         "alpha2Code": "AT",
#         "alpha3Code": "AUT",
#         "altSpellings": [
#             "AT",
#             "\u00d6sterreich",
#             "Osterreich",
#             "Oesterreich"
#         ],
#         "area": 83871.0,
#         "borders": [
#             "CZE",
#             "DEU",
#             "HUN",
#             "ITA",
#             "LIE",
#             "SVK",
#             "SVN",
#             "CHE"
#         ],
#         "callingCodes": [
#             "43"
#         ],
#         "capital": "Vienna",
#         "cioc": "AUT",
#         "currencies": [
#             {
#                 "code": "EUR",
#                 "name": "Euro",
#                 "symbol": "\u20ac"
#             }
#         ],
#         "demonym": "Austrian",
#         "flag": "https://restcountries.eu/data/aut.svg",
#         "gini": 26.0,
#         "languages": [
#             {
#                 "iso639_1": "de",
#                 "iso639_2": "deu",
#                 "name": "German",
#                 "nativeName": "Deutsch"
#             }
#         ],
#         "latlng": [
#             47.33333333,
#             13.33333333
#         ],
#         "name": "Austria",
#         "nativeName": "\u00d6sterreich",
#         "numericCode": "040",
#         "population": 8725931,
#         "region": "Europe",
#         "regionalBlocs": [
#             {
#                 "acronym": "EU",
#                 "name": "European Union",
#                 "otherAcronyms": [],
#                 "otherNames": []
#             }
#         ],
#         "subregion": "Western Europe",
#         "timezones": [
#             "UTC+01:00"
#         ],
#         "topLevelDomain": [
#             ".at"
#         ],
#         "translations": {
#             "br": "\u00e1ustria",
#             "de": "\u00d6sterreich",
#             "es": "Austria",
#             "fa": "\u0627\u062a\u0631\u06cc\u0634",
#             "fr": "Autriche",
#             "hr": "Austrija",
#             "it": "Austria",
#             "ja": "\u30aa\u30fc\u30b9\u30c8\u30ea\u30a2",
#             "nl": "Oostenrijk",
#             "pt": "\u00e1ustria"
#         }
#     },
#     {
#         "alpha2Code": "AZ",
#         "alpha3Code": "AZE",
#         "altSpellings": [
#             "AZ",
#             "Republic of Azerbaijan",
#             "Az\u0259rbaycan Respublikas\u0131"
#         ],
#         "area": 86600.0,
#         "borders": [
#             "ARM",
#             "GEO",
#             "IRN",
#             "RUS",
#             "TUR"
#         ],
#         "callingCodes": [
#             "994"
#         ],
#         "capital": "Baku",
#         "cioc": "AZE",
#         "currencies": [
#             {
#                 "code": "AZN",
#                 "name": "Azerbaijani manat",
#                 "symbol": null
#             }
#         ],
#         "demonym": "Azerbaijani",
#         "flag": "https://restcountries.eu/data/aze.svg",
#         "gini": 33.7,
#         "languages": [
#             {
#                 "iso639_1": "az",
#                 "iso639_2": "aze",
#                 "name": "Azerbaijani",
#                 "nativeName": "az\u0259rbaycan dili"
#             }
#         ],
#         "latlng": [
#             40.5,
#             47.5
#         ],
#         "name": "Azerbaijan",
#         "nativeName": "Az\u0259rbaycan",
#         "numericCode": "031",
#         "population": 9730500,
#         "region": "Asia",
#         "regionalBlocs": [],
#         "subregion": "Western Asia",
#         "timezones": [
#             "UTC+04:00"
#         ],
#         "topLevelDomain": [
#             ".az"
#         ],
#         "translations": {
#             "br": "Azerbaij\u00e3o",
#             "de": "Aserbaidschan",
#             "es": "Azerbaiy\u00e1n",
#             "fa": "\u0622\u0630\u0631\u0628\u0627\u06cc\u062c\u0627\u0646",
#             "fr": "Azerba\u00efdjan",
#             "hr": "Azerbajd\u017ean",
#             "it": "Azerbaijan",
#             "ja": "\u30a2\u30bc\u30eb\u30d0\u30a4\u30b8\u30e3\u30f3",
#             "nl": "Azerbeidzjan",
#             "pt": "Azerbaij\u00e3o"
#         }
#     },
#     {
#         "alpha2Code": "BS",
#         "alpha3Code": "BHS",
#         "altSpellings": [
#             "BS",
#             "Commonwealth of the Bahamas"
#         ],
#         "area": 13943.0,
#         "borders": [],
#         "callingCodes": [
#             "1242"
#         ],
#         "capital": "Nassau",
#         "cioc": "BAH",
#         "currencies": [
#             {
#                 "code": "BSD",
#                 "name": "Bahamian dollar",
#                 "symbol": "$"
#             }
#         ],
#         "demonym": "Bahamian",
#         "flag": "https://restcountries.eu/data/bhs.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "en",
#                 "iso639_2": "eng",
#                 "name": "English",
#                 "nativeName": "English"
#             }
#         ],
#         "latlng": [
#             24.25,
#             -76.0
#         ],
#         "name": "Bahamas",
#         "nativeName": "Bahamas",
#         "numericCode": "044",
#         "population": 378040,
#         "region": "Americas",
#         "regionalBlocs": [
#             {
#                 "acronym": "CARICOM",
#                 "name": "Caribbean Community",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "Comunidad del Caribe",
#                     "Communaut\u00e9 Carib\u00e9enne",
#                     "Caribische Gemeenschap"
#                 ]
#             }
#         ],
#         "subregion": "Caribbean",
#         "timezones": [
#             "UTC-05:00"
#         ],
#         "topLevelDomain": [
#             ".bs"
#         ],
#         "translations": {
#             "br": "Bahamas",
#             "de": "Bahamas",
#             "es": "Bahamas",
#             "fa": "\u0628\u0627\u0647\u0627\u0645\u0627",
#             "fr": "Bahamas",
#             "hr": "Bahami",
#             "it": "Bahamas",
#             "ja": "\u30d0\u30cf\u30de",
#             "nl": "Bahama\u2019s",
#             "pt": "Baamas"
#         }
#     },
#     {
#         "alpha2Code": "BH",
#         "alpha3Code": "BHR",
#         "altSpellings": [
#             "BH",
#             "Kingdom of Bahrain",
#             "Mamlakat al-Ba\u1e25rayn"
#         ],
#         "area": 765.0,
#         "borders": [],
#         "callingCodes": [
#             "973"
#         ],
#         "capital": "Manama",
#         "cioc": "BRN",
#         "currencies": [
#             {
#                 "code": "BHD",
#                 "name": "Bahraini dinar",
#                 "symbol": ".\u062f.\u0628"
#             }
#         ],
#         "demonym": "Bahraini",
#         "flag": "https://restcountries.eu/data/bhr.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "ar",
#                 "iso639_2": "ara",
#                 "name": "Arabic",
#                 "nativeName": "\u0627\u0644\u0639\u0631\u0628\u064a\u0629"
#             }
#         ],
#         "latlng": [
#             26.0,
#             50.55
#         ],
#         "name": "Bahrain",
#         "nativeName": "\u200f\u0627\u0644\u0628\u062d\u0631\u064a\u0646",
#         "numericCode": "048",
#         "population": 1404900,
#         "region": "Asia",
#         "regionalBlocs": [
#             {
#                 "acronym": "AL",
#                 "name": "Arab League",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "\u062c\u0627\u0645\u0639\u0629 \u0627\u0644\u062f\u0648\u0644 \u0627\u0644\u0639\u0631\u0628\u064a\u0629",
#                     "J\u0101mi\u02bbat ad-Duwal al-\u02bbArab\u012byah",
#                     "League of Arab States"
#                 ]
#             }
#         ],
#         "subregion": "Western Asia",
#         "timezones": [
#             "UTC+03:00"
#         ],
#         "topLevelDomain": [
#             ".bh"
#         ],
#         "translations": {
#             "br": "Bahrein",
#             "de": "Bahrain",
#             "es": "Bahrein",
#             "fa": "\u0628\u062d\u0631\u06cc\u0646",
#             "fr": "Bahre\u00efn",
#             "hr": "Bahrein",
#             "it": "Bahrein",
#             "ja": "\u30d0\u30fc\u30ec\u30fc\u30f3",
#             "nl": "Bahrein",
#             "pt": "Bar\u00e9m"
#         }
#     },
#     {
#         "alpha2Code": "BD",
#         "alpha3Code": "BGD",
#         "altSpellings": [
#             "BD",
#             "People's Republic of Bangladesh",
#             "G\u00f4n\u00f4pr\u00f4jat\u00f4ntri Bangladesh"
#         ],
#         "area": 147570.0,
#         "borders": [
#             "MMR",
#             "IND"
#         ],
#         "callingCodes": [
#             "880"
#         ],
#         "capital": "Dhaka",
#         "cioc": "BAN",
#         "currencies": [
#             {
#                 "code": "BDT",
#                 "name": "Bangladeshi taka",
#                 "symbol": "\u09f3"
#             }
#         ],
#         "demonym": "Bangladeshi",
#         "flag": "https://restcountries.eu/data/bgd.svg",
#         "gini": 32.1,
#         "languages": [
#             {
#                 "iso639_1": "bn",
#                 "iso639_2": "ben",
#                 "name": "Bengali",
#                 "nativeName": "\u09ac\u09be\u0982\u09b2\u09be"
#             }
#         ],
#         "latlng": [
#             24.0,
#             90.0
#         ],
#         "name": "Bangladesh",
#         "nativeName": "Bangladesh",
#         "numericCode": "050",
#         "population": 161006790,
#         "region": "Asia",
#         "regionalBlocs": [
#             {
#                 "acronym": "SAARC",
#                 "name": "South Asian Association for Regional Cooperation",
#                 "otherAcronyms": [],
#                 "otherNames": []
#             }
#         ],
#         "subregion": "Southern Asia",
#         "timezones": [
#             "UTC+06:00"
#         ],
#         "topLevelDomain": [
#             ".bd"
#         ],
#         "translations": {
#             "br": "Bangladesh",
#             "de": "Bangladesch",
#             "es": "Bangladesh",
#             "fa": "\u0628\u0646\u06af\u0644\u0627\u062f\u0634",
#             "fr": "Bangladesh",
#             "hr": "Banglade\u0161",
#             "it": "Bangladesh",
#             "ja": "\u30d0\u30f3\u30b0\u30e9\u30c7\u30b7\u30e5",
#             "nl": "Bangladesh",
#             "pt": "Bangladeche"
#         }
#     },
#     {
#         "alpha2Code": "BB",
#         "alpha3Code": "BRB",
#         "altSpellings": [
#             "BB"
#         ],
#         "area": 430.0,
#         "borders": [],
#         "callingCodes": [
#             "1246"
#         ],
#         "capital": "Bridgetown",
#         "cioc": "BAR",
#         "currencies": [
#             {
#                 "code": "BBD",
#                 "name": "Barbadian dollar",
#                 "symbol": "$"
#             }
#         ],
#         "demonym": "Barbadian",
#         "flag": "https://restcountries.eu/data/brb.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "en",
#                 "iso639_2": "eng",
#                 "name": "English",
#                 "nativeName": "English"
#             }
#         ],
#         "latlng": [
#             13.16666666,
#             -59.53333333
#         ],
#         "name": "Barbados",
#         "nativeName": "Barbados",
#         "numericCode": "052",
#         "population": 285000,
#         "region": "Americas",
#         "regionalBlocs": [
#             {
#                 "acronym": "CARICOM",
#                 "name": "Caribbean Community",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "Comunidad del Caribe",
#                     "Communaut\u00e9 Carib\u00e9enne",
#                     "Caribische Gemeenschap"
#                 ]
#             }
#         ],
#         "subregion": "Caribbean",
#         "timezones": [
#             "UTC-04:00"
#         ],
#         "topLevelDomain": [
#             ".bb"
#         ],
#         "translations": {
#             "br": "Barbados",
#             "de": "Barbados",
#             "es": "Barbados",
#             "fa": "\u0628\u0627\u0631\u0628\u0627\u062f\u0648\u0633",
#             "fr": "Barbade",
#             "hr": "Barbados",
#             "it": "Barbados",
#             "ja": "\u30d0\u30eb\u30d0\u30c9\u30b9",
#             "nl": "Barbados",
#             "pt": "Barbados"
#         }
#     },
#     {
#         "alpha2Code": "BY",
#         "alpha3Code": "BLR",
#         "altSpellings": [
#             "BY",
#             "Bielaru\u015b",
#             "Republic of Belarus",
#             "\u0411\u0435\u043b\u043e\u0440\u0443\u0441\u0441\u0438\u044f",
#             "\u0420\u0435\u0441\u043f\u0443\u0431\u043b\u0438\u043a\u0430 \u0411\u0435\u043b\u0430\u0440\u0443\u0441\u044c",
#             "Belorussiya",
#             "Respublika Belarus\u2019"
#         ],
#         "area": 207600.0,
#         "borders": [
#             "LVA",
#             "LTU",
#             "POL",
#             "RUS",
#             "UKR"
#         ],
#         "callingCodes": [
#             "375"
#         ],
#         "capital": "Minsk",
#         "cioc": "BLR",
#         "currencies": [
#             {
#                 "code": "BYN",
#                 "name": "New Belarusian ruble",
#                 "symbol": "Br"
#             },
#             {
#                 "code": "BYR",
#                 "name": "Old Belarusian ruble",
#                 "symbol": "Br"
#             }
#         ],
#         "demonym": "Belarusian",
#         "flag": "https://restcountries.eu/data/blr.svg",
#         "gini": 26.5,
#         "languages": [
#             {
#                 "iso639_1": "be",
#                 "iso639_2": "bel",
#                 "name": "Belarusian",
#                 "nativeName": "\u0431\u0435\u043b\u0430\u0440\u0443\u0441\u043a\u0430\u044f \u043c\u043e\u0432\u0430"
#             },
#             {
#                 "iso639_1": "ru",
#                 "iso639_2": "rus",
#                 "name": "Russian",
#                 "nativeName": "\u0420\u0443\u0441\u0441\u043a\u0438\u0439"
#             }
#         ],
#         "latlng": [
#             53.0,
#             28.0
#         ],
#         "name": "Belarus",
#         "nativeName": "\u0411\u0435\u043b\u0430\u0440\u0443\u0301\u0441\u044c",
#         "numericCode": "112",
#         "population": 9498700,
#         "region": "Europe",
#         "regionalBlocs": [
#             {
#                 "acronym": "EEU",
#                 "name": "Eurasian Economic Union",
#                 "otherAcronyms": [
#                     "EAEU"
#                 ],
#                 "otherNames": []
#             }
#         ],
#         "subregion": "Eastern Europe",
#         "timezones": [
#             "UTC+03:00"
#         ],
#         "topLevelDomain": [
#             ".by"
#         ],
#         "translations": {
#             "br": "Bielorr\u00fassia",
#             "de": "Wei\u00dfrussland",
#             "es": "Bielorrusia",
#             "fa": "\u0628\u0644\u0627\u0631\u0648\u0633",
#             "fr": "Bi\u00e9lorussie",
#             "hr": "Bjelorusija",
#             "it": "Bielorussia",
#             "ja": "\u30d9\u30e9\u30eb\u30fc\u30b7",
#             "nl": "Wit-Rusland",
#             "pt": "Bielorr\u00fassia"
#         }
#     },
#     {
#         "alpha2Code": "BE",
#         "alpha3Code": "BEL",
#         "altSpellings": [
#             "BE",
#             "Belgi\u00eb",
#             "Belgie",
#             "Belgien",
#             "Belgique",
#             "Kingdom of Belgium",
#             "Koninkrijk Belgi\u00eb",
#             "Royaume de Belgique",
#             "K\u00f6nigreich Belgien"
#         ],
#         "area": 30528.0,
#         "borders": [
#             "FRA",
#             "DEU",
#             "LUX",
#             "NLD"
#         ],
#         "callingCodes": [
#             "32"
#         ],
#         "capital": "Brussels",
#         "cioc": "BEL",
#         "currencies": [
#             {
#                 "code": "EUR",
#                 "name": "Euro",
#                 "symbol": "\u20ac"
#             }
#         ],
#         "demonym": "Belgian",
#         "flag": "https://restcountries.eu/data/bel.svg",
#         "gini": 33.0,
#         "languages": [
#             {
#                 "iso639_1": "nl",
#                 "iso639_2": "nld",
#                 "name": "Dutch",
#                 "nativeName": "Nederlands"
#             },
#             {
#                 "iso639_1": "fr",
#                 "iso639_2": "fra",
#                 "name": "French",
#                 "nativeName": "fran\u00e7ais"
#             },
#             {
#                 "iso639_1": "de",
#                 "iso639_2": "deu",
#                 "name": "German",
#                 "nativeName": "Deutsch"
#             }
#         ],
#         "latlng": [
#             50.83333333,
#             4.0
#         ],
#         "name": "Belgium",
#         "nativeName": "Belgi\u00eb",
#         "numericCode": "056",
#         "population": 11319511,
#         "region": "Europe",
#         "regionalBlocs": [
#             {
#                 "acronym": "EU",
#                 "name": "European Union",
#                 "otherAcronyms": [],
#                 "otherNames": []
#             }
#         ],
#         "subregion": "Western Europe",
#         "timezones": [
#             "UTC+01:00"
#         ],
#         "topLevelDomain": [
#             ".be"
#         ],
#         "translations": {
#             "br": "B\u00e9lgica",
#             "de": "Belgien",
#             "es": "B\u00e9lgica",
#             "fa": "\u0628\u0644\u0698\u06cc\u06a9",
#             "fr": "Belgique",
#             "hr": "Belgija",
#             "it": "Belgio",
#             "ja": "\u30d9\u30eb\u30ae\u30fc",
#             "nl": "Belgi\u00eb",
#             "pt": "B\u00e9lgica"
#         }
#     },
#     {
#         "alpha2Code": "BZ",
#         "alpha3Code": "BLZ",
#         "altSpellings": [
#             "BZ"
#         ],
#         "area": 22966.0,
#         "borders": [
#             "GTM",
#             "MEX"
#         ],
#         "callingCodes": [
#             "501"
#         ],
#         "capital": "Belmopan",
#         "cioc": "BIZ",
#         "currencies": [
#             {
#                 "code": "BZD",
#                 "name": "Belize dollar",
#                 "symbol": "$"
#             }
#         ],
#         "demonym": "Belizean",
#         "flag": "https://restcountries.eu/data/blz.svg",
#         "gini": 53.1,
#         "languages": [
#             {
#                 "iso639_1": "en",
#                 "iso639_2": "eng",
#                 "name": "English",
#                 "nativeName": "English"
#             },
#             {
#                 "iso639_1": "es",
#                 "iso639_2": "spa",
#                 "name": "Spanish",
#                 "nativeName": "Espa\u00f1ol"
#             }
#         ],
#         "latlng": [
#             17.25,
#             -88.75
#         ],
#         "name": "Belize",
#         "nativeName": "Belize",
#         "numericCode": "084",
#         "population": 370300,
#         "region": "Americas",
#         "regionalBlocs": [
#             {
#                 "acronym": "CARICOM",
#                 "name": "Caribbean Community",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "Comunidad del Caribe",
#                     "Communaut\u00e9 Carib\u00e9enne",
#                     "Caribische Gemeenschap"
#                 ]
#             },
#             {
#                 "acronym": "CAIS",
#                 "name": "Central American Integration System",
#                 "otherAcronyms": [
#                     "SICA"
#                 ],
#                 "otherNames": [
#                     "Sistema de la Integraci\u00f3n Centroamericana,"
#                 ]
#             }
#         ],
#         "subregion": "Central America",
#         "timezones": [
#             "UTC-06:00"
#         ],
#         "topLevelDomain": [
#             ".bz"
# ...
#         "flag": "https://restcountries.eu/data/ven.svg",
#         "gini": 44.8,
#         "languages": [
#             {
#                 "iso639_1": "es",
#                 "iso639_2": "spa",
#                 "name": "Spanish",
#                 "nativeName": "Espa\u00f1ol"
#             }
#         ],
#         "latlng": [
#             8.0,
#             -66.0
#         ],
#         "name": "Venezuela (Bolivarian Republic of)",
#         "nativeName": "Venezuela",
#         "numericCode": "862",
#         "population": 31028700,
#         "region": "Americas",
#         "regionalBlocs": [
#             {
#                 "acronym": "USAN",
#                 "name": "Union of South American Nations",
#                 "otherAcronyms": [
#                     "UNASUR",
#                     "UNASUL",
#                     "UZAN"
#                 ],
#                 "otherNames": [
#                     "Uni\u00f3n de Naciones Suramericanas",
#                     "Uni\u00e3o de Na\u00e7\u00f5es Sul-Americanas",
#                     "Unie van Zuid-Amerikaanse Naties",
#                     "South American Union"
#                 ]
#             }
#         ],
#         "subregion": "South America",
#         "timezones": [
#             "UTC-04:00"
#         ],
#         "topLevelDomain": [
#             ".ve"
#         ],
#         "translations": {
#             "br": "Venezuela",
#             "de": "Venezuela",
#             "es": "Venezuela",
#             "fa": "\u0648\u0646\u0632\u0648\u0626\u0644\u0627",
#             "fr": "Venezuela",
#             "hr": "Venezuela",
#             "it": "Venezuela",
#             "ja": "\u30d9\u30cd\u30ba\u30a8\u30e9\u30fb\u30dc\u30ea\u30d0\u30eb\u5171\u548c\u56fd",
#             "nl": "Venezuela",
#             "pt": "Venezuela"
#         }
#     },
#     {
#         "alpha2Code": "VN",
#         "alpha3Code": "VNM",
#         "altSpellings": [
#             "VN",
#             "Socialist Republic of Vietnam",
#             "C\u1ed9ng h\u00f2a X\u00e3 h\u1ed9i ch\u1ee7 ngh\u0129a Vi\u1ec7t Nam"
#         ],
#         "area": 331212.0,
#         "borders": [
#             "KHM",
#             "CHN",
#             "LAO"
#         ],
#         "callingCodes": [
#             "84"
#         ],
#         "capital": "Hanoi",
#         "cioc": "VIE",
#         "currencies": [
#             {
#                 "code": "VND",
#                 "name": "Vietnamese \u0111\u1ed3ng",
#                 "symbol": "\u20ab"
#             }
#         ],
#         "demonym": "Vietnamese",
#         "flag": "https://restcountries.eu/data/vnm.svg",
#         "gini": 35.6,
#         "languages": [
#             {
#                 "iso639_1": "vi",
#                 "iso639_2": "vie",
#                 "name": "Vietnamese",
#                 "nativeName": "Ti\u1ebfng Vi\u1ec7t"
#             }
#         ],
#         "latlng": [
#             16.16666666,
#             107.83333333
#         ],
#         "name": "Viet Nam",
#         "nativeName": "Vi\u1ec7t Nam",
#         "numericCode": "704",
#         "population": 92700000,
#         "region": "Asia",
#         "regionalBlocs": [
#             {
#                 "acronym": "ASEAN",
#                 "name": "Association of Southeast Asian Nations",
#                 "otherAcronyms": [],
#                 "otherNames": []
#             }
#         ],
#         "subregion": "South-Eastern Asia",
#         "timezones": [
#             "UTC+07:00"
#         ],
#         "topLevelDomain": [
#             ".vn"
#         ],
#         "translations": {
#             "br": "Vietn\u00e3",
#             "de": "Vietnam",
#             "es": "Vietnam",
#             "fa": "\u0648\u06cc\u062a\u0646\u0627\u0645",
#             "fr": "Vi\u00eat Nam",
#             "hr": "Vijetnam",
#             "it": "Vietnam",
#             "ja": "\u30d9\u30c8\u30ca\u30e0",
#             "nl": "Vietnam",
#             "pt": "Vietname"
#         }
#     },
#     {
#         "alpha2Code": "WF",
#         "alpha3Code": "WLF",
#         "altSpellings": [
#             "WF",
#             "Territory of the Wallis and Futuna Islands",
#             "Territoire des \u00eeles Wallis et Futuna"
#         ],
#         "area": 142.0,
#         "borders": [],
#         "callingCodes": [
#             "681"
#         ],
#         "capital": "Mata-Utu",
#         "cioc": "",
#         "currencies": [
#             {
#                 "code": "XPF",
#                 "name": "CFP franc",
#                 "symbol": "Fr"
#             }
#         ],
#         "demonym": "Wallis and Futuna Islander",
#         "flag": "https://restcountries.eu/data/wlf.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "fr",
#                 "iso639_2": "fra",
#                 "name": "French",
#                 "nativeName": "fran\u00e7ais"
#             }
#         ],
#         "latlng": [
#             -13.3,
#             -176.2
#         ],
#         "name": "Wallis and Futuna",
#         "nativeName": "Wallis et Futuna",
#         "numericCode": "876",
#         "population": 11750,
#         "region": "Oceania",
#         "regionalBlocs": [],
#         "subregion": "Polynesia",
#         "timezones": [
#             "UTC+12:00"
#         ],
#         "topLevelDomain": [
#             ".wf"
#         ],
#         "translations": {
#             "br": "Wallis e Futuna",
#             "de": "Wallis und Futuna",
#             "es": "Wallis y Futuna",
#             "fa": "\u0648\u0627\u0644\u06cc\u0633 \u0648 \u0641\u0648\u062a\u0648\u0646\u0627",
#             "fr": "Wallis-et-Futuna",
#             "hr": "Wallis i Fortuna",
#             "it": "Wallis e Futuna",
#             "ja": "\u30a6\u30a9\u30ea\u30b9\u30fb\u30d5\u30c4\u30ca",
#             "nl": "Wallis en Futuna",
#             "pt": "Wallis e Futuna"
#         }
#     },
#     {
#         "alpha2Code": "EH",
#         "alpha3Code": "ESH",
#         "altSpellings": [
#             "EH",
#             "Tane\u1e93roft Tutrimt"
#         ],
#         "area": 266000.0,
#         "borders": [
#             "DZA",
#             "MRT",
#             "MAR"
#         ],
#         "callingCodes": [
#             "212"
#         ],
#         "capital": "El Aai\u00fan",
#         "cioc": "",
#         "currencies": [
#             {
#                 "code": "MAD",
#                 "name": "Moroccan dirham",
#                 "symbol": "\u062f.\u0645."
#             },
#             {
#                 "code": "DZD",
#                 "name": "Algerian dinar",
#                 "symbol": "\u062f.\u062c"
#             }
#         ],
#         "demonym": "Sahrawi",
#         "flag": "https://restcountries.eu/data/esh.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "es",
#                 "iso639_2": "spa",
#                 "name": "Spanish",
#                 "nativeName": "Espa\u00f1ol"
#             }
#         ],
#         "latlng": [
#             24.5,
#             -13.0
#         ],
#         "name": "Western Sahara",
#         "nativeName": "\u0627\u0644\u0635\u062d\u0631\u0627\u0621 \u0627\u0644\u063a\u0631\u0628\u064a\u0629",
#         "numericCode": "732",
#         "population": 510713,
#         "region": "Africa",
#         "regionalBlocs": [
#             {
#                 "acronym": "AU",
#                 "name": "African Union",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "\u0627\u0644\u0627\u062a\u062d\u0627\u062f \u0627\u0644\u0623\u0641\u0631\u064a\u0642\u064a",
#                     "Union africaine",
#                     "Uni\u00e3o Africana",
#                     "Uni\u00f3n Africana",
#                     "Umoja wa Afrika"
#                 ]
#             }
#         ],
#         "subregion": "Northern Africa",
#         "timezones": [
#             "UTC+00:00"
#         ],
#         "topLevelDomain": [
#             ".eh"
#         ],
#         "translations": {
#             "br": "Saara Ocidental",
#             "de": "Westsahara",
#             "es": "Sahara Occidental",
#             "fa": "\u062c\u0645\u0647\u0648\u0631\u06cc \u062f\u0645\u0648\u06a9\u0631\u0627\u062a\u06cc\u06a9 \u0639\u0631\u0628\u06cc \u0635\u062d\u0631\u0627",
#             "fr": "Sahara Occidental",
#             "hr": "Zapadna Sahara",
#             "it": "Sahara Occidentale",
#             "ja": "\u897f\u30b5\u30cf\u30e9",
#             "nl": "Westelijke Sahara",
#             "pt": "Saara Ocidental"
#         }
#     },
#     {
#         "alpha2Code": "YE",
#         "alpha3Code": "YEM",
#         "altSpellings": [
#             "YE",
#             "Yemeni Republic",
#             "al-Jumh\u016briyyah al-Yamaniyyah"
#         ],
#         "area": 527968.0,
#         "borders": [
#             "OMN",
#             "SAU"
#         ],
#         "callingCodes": [
#             "967"
#         ],
#         "capital": "Sana'a",
#         "cioc": "YEM",
#         "currencies": [
#             {
#                 "code": "YER",
#                 "name": "Yemeni rial",
#                 "symbol": "\ufdfc"
#             }
#         ],
#         "demonym": "Yemeni",
#         "flag": "https://restcountries.eu/data/yem.svg",
#         "gini": 37.7,
#         "languages": [
#             {
#                 "iso639_1": "ar",
#                 "iso639_2": "ara",
#                 "name": "Arabic",
#                 "nativeName": "\u0627\u0644\u0639\u0631\u0628\u064a\u0629"
#             }
#         ],
#         "latlng": [
#             15.0,
#             48.0
#         ],
#         "name": "Yemen",
#         "nativeName": "\u0627\u0644\u064a\u064e\u0645\u064e\u0646",
#         "numericCode": "887",
#         "population": 27478000,
#         "region": "Asia",
#         "regionalBlocs": [
#             {
#                 "acronym": "AL",
#                 "name": "Arab League",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "\u062c\u0627\u0645\u0639\u0629 \u0627\u0644\u062f\u0648\u0644 \u0627\u0644\u0639\u0631\u0628\u064a\u0629",
#                     "J\u0101mi\u02bbat ad-Duwal al-\u02bbArab\u012byah",
#                     "League of Arab States"
#                 ]
#             }
#         ],
#         "subregion": "Western Asia",
#         "timezones": [
#             "UTC+03:00"
#         ],
#         "topLevelDomain": [
#             ".ye"
#         ],
#         "translations": {
#             "br": "I\u00eamen",
#             "de": "Jemen",
#             "es": "Yemen",
#             "fa": "\u06cc\u0645\u0646",
#             "fr": "Y\u00e9men",
#             "hr": "Jemen",
#             "it": "Yemen",
#             "ja": "\u30a4\u30a8\u30e1\u30f3",
#             "nl": "Jemen",
#             "pt": "I\u00e9men"
#         }
#     },
#     {
#         "alpha2Code": "ZM",
#         "alpha3Code": "ZMB",
#         "altSpellings": [
#             "ZM",
#             "Republic of Zambia"
#         ],
#         "area": 752612.0,
#         "borders": [
#             "AGO",
#             "BWA",
#             "COD",
#             "MWI",
#             "MOZ",
#             "NAM",
#             "TZA",
#             "ZWE"
#         ],
#         "callingCodes": [
#             "260"
#         ],
#         "capital": "Lusaka",
#         "cioc": "ZAM",
#         "currencies": [
#             {
#                 "code": "ZMW",
#                 "name": "Zambian kwacha",
#                 "symbol": "ZK"
#             }
#         ],
#         "demonym": "Zambian",
#         "flag": "https://restcountries.eu/data/zmb.svg",
#         "gini": 54.6,
#         "languages": [
#             {
#                 "iso639_1": "en",
#                 "iso639_2": "eng",
#                 "name": "English",
#                 "nativeName": "English"
#             }
#         ],
#         "latlng": [
#             -15.0,
#             30.0
#         ],
#         "name": "Zambia",
#         "nativeName": "Zambia",
#         "numericCode": "894",
#         "population": 15933883,
#         "region": "Africa",
#         "regionalBlocs": [
#             {
#                 "acronym": "AU",
#                 "name": "African Union",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "\u0627\u0644\u0627\u062a\u062d\u0627\u062f \u0627\u0644\u0623\u0641\u0631\u064a\u0642\u064a",
#                     "Union africaine",
#                     "Uni\u00e3o Africana",
#                     "Uni\u00f3n Africana",
#                     "Umoja wa Afrika"
#                 ]
#             }
#         ],
#         "subregion": "Eastern Africa",
#         "timezones": [
#             "UTC+02:00"
#         ],
#         "topLevelDomain": [
#             ".zm"
#         ],
#         "translations": {
#             "br": "Z\u00e2mbia",
#             "de": "Sambia",
#             "es": "Zambia",
#             "fa": "\u0632\u0627\u0645\u0628\u06cc\u0627",
#             "fr": "Zambie",
#             "hr": "Zambija",
#             "it": "Zambia",
#             "ja": "\u30b6\u30f3\u30d3\u30a2",
#             "nl": "Zambia",
#             "pt": "Z\u00e2mbia"
#         }
#     },
#     {
#         "alpha2Code": "ZW",
#         "alpha3Code": "ZWE",
#         "altSpellings": [
#             "ZW",
#             "Republic of Zimbabwe"
#         ],
#         "area": 390757.0,
#         "borders": [
#             "BWA",
#             "MOZ",
#             "ZAF",
#             "ZMB"
#         ],
#         "callingCodes": [
#             "263"
#         ],
#         "capital": "Harare",
#         "cioc": "ZIM",
#         "currencies": [
#             {
#                 "code": "BWP",
#                 "name": "Botswana pula",
#                 "symbol": "P"
#             },
#             {
#                 "code": "GBP",
#                 "name": "British pound",
#                 "symbol": "\u00a3"
#             },
#             {
#                 "code": "CNY",
#                 "name": "Chinese yuan",
#                 "symbol": "\u00a5"
#             },
#             {
#                 "code": "EUR",
#                 "name": "Euro",
#                 "symbol": "\u20ac"
#             },
#             {
#                 "code": "INR",
#                 "name": "Indian rupee",
#                 "symbol": "\u20b9"
#             },
#             {
#                 "code": "JPY",
#                 "name": "Japanese yen",
#                 "symbol": "\u00a5"
#             },
#             {
#                 "code": "ZAR",
#                 "name": "South African rand",
#                 "symbol": "Rs"
#             },
#             {
#                 "code": "USD",
#                 "name": "United States dollar",
#                 "symbol": "$"
#             },
#             {
#                 "code": "(none)",
#                 "name": null,
#                 "symbol": null
#             }
#         ],
#         "demonym": "Zimbabwean",
#         "flag": "https://restcountries.eu/data/zwe.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "en",
#                 "iso639_2": "eng",
#                 "name": "English",
#                 "nativeName": "English"
#             },
#             {
#                 "iso639_1": "sn",
#                 "iso639_2": "sna",
#                 "name": "Shona",
#                 "nativeName": "chiShona"
#             },
#             {
#                 "iso639_1": "nd",
#                 "iso639_2": "nde",
#                 "name": "Northern Ndebele",
#                 "nativeName": "isiNdebele"
#             }
#         ],
#         "latlng": [
#             -20.0,
#             30.0
#         ],
#         "name": "Zimbabwe",
#         "nativeName": "Zimbabwe",
#         "numericCode": "716",
#         "population": 14240168,
#         "region": "Africa",
#         "regionalBlocs": [
#             {
#                 "acronym": "AU",
#                 "name": "African Union",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "\u0627\u0644\u0627\u062a\u062d\u0627\u062f \u0627\u0644\u0623\u0641\u0631\u064a\u0642\u064a",
#                     "Union africaine",
#                     "Uni\u00e3o Africana",
#                     "Uni\u00f3n Africana",
#                     "Umoja wa Afrika"
#                 ]
#             }
#         ],
#         "subregion": "Eastern Africa",
#         "timezones": [
#             "UTC+02:00"
#         ],
#         "topLevelDomain": [
#             ".zw"
#         ],
#         "translations": {
#             "br": "Zimbabwe",
#             "de": "Simbabwe",
#             "es": "Zimbabue",
#             "fa": "\u0632\u06cc\u0645\u0628\u0627\u0648\u0647",
#             "fr": "Zimbabwe",
#             "hr": "Zimbabve",
#             "it": "Zimbabwe",
#             "ja": "\u30b8\u30f3\u30d0\u30d6\u30a8",
#             "nl": "Zimbabwe",
#             "pt": "Zimbabu\u00e9"
#         }
#     }
# ]

# %%
# Determine how many countries are included in this data set
nCountriesCodes = len(country_data)

# Initialize lists
nameCountry = []       # name of country
a3cCountry = []        # ISO 3166-1 3-letter country code
latlng = []            # geocache data

# Start gathering data for all countries. 
# If a country's data can not be obtained then skip entry and move on to the next...

for code in np.arange(0,nCountriesCodes,1):
    
    try:
        nameCountry.append(country_data[code]["name"])
        a3cCountry.append(country_data[code]["alpha3Code"])
        latlng.append(country_data[code]["latlng"])

    except:
        print(f"Country Not Listed in index {code}... skipping.")

# %%
# Construct dataframe from with hospital data lists
raw_codes_df = pd.DataFrame({"Country":nameCountry,
                                "Code":a3cCountry,
                                "Location":latlng})
raw_codes_df.head()
# Out:
#           Country Code                Location
# 0     Afghanistan  AFG            [33.0, 65.0]
# 1   Åland Islands  ALA       [60.116667, 19.9]
# 2         Albania  ALB            [41.0, 20.0]
# 3         Algeria  DZA             [28.0, 3.0]
# 4  American Samoa  ASM  [-14.33333333, -170.0]

# %% [markdown]
# ### Add country codes to hospital bed dataframe

# %%
# Add country code and location data to hospital bed dataframe
total_df = hospitalBedData.merge(raw_codes_df,left_on= "Country",right_on="Country",how="left")

# The following countries were not merged correctly (i.e., country names differ in spelling)
unfoundCountries = total_df.loc[pd.isnull(total_df["Code"])]
print(f"List of unmatched coutries:\n{unfoundCountries['Country']}")
# Out:
# List of unmatched coutries:
# 43                                   Czechia
# 45     Democratic People's Republic of Korea
# 46          Democratic Republic of the Congo
# 56                                  Eswatini
# 132                        Republic of Korea
# 133                      Republic of Moldova
# 134              Republic of North Macedonia
# 172              United Republic of Tanzania
# Name: Country, dtype: object

# %%
# Rather than remove unmerged countries, manual corrections will be made to not jeopardize the data set
corrections = {"Czechia":"Czech Republic",
              "Democratic People's Republic of Korea":"Korea (Democratic People's Republic of)",
              "Republic of Korea":"Korea (Republic of)",
              "Democratic Republic of the Congo":"Congo (Democratic Republic of the)",
              "Eswatini":"Swaziland",
              "Republic of Moldova":"Moldova (Republic of)",
              "Republic of North Macedonia":"Macedonia (the former Yugoslav Republic of)",
              "United Republic of Tanzania":"Tanzania, United Republic of"}

# Make name corrections into hospital bed data set
for country in corrections:
    oldName = country
    newName = corrections[country]
    hospitalBedData.loc[hospitalBedData["Country"] == oldName,"Country"] = newName

# %%
# Merge again...
total_df = hospitalBedData.merge(raw_codes_df,left_on= "Country",right_on="Country",how="left")

# We should have a complete merge!
unfoundCountries = total_df.loc[pd.isnull(total_df["Code"])]
print(f"List of unmatched coutries:\n {unfoundCountries}")
# Out:
# List of unmatched coutries:
#  Empty DataFrame
# Columns: [Country, Region, Latest Beds, Code, Location]
# Index: []

# %% [markdown]
# ### Data Retrieval: World Bank API - Income per capita

# %%
# Create the desired URL for World Bank data requests

# World Bank Organization corresponding to desired indicator: 
# Gross National Income, converted to U.S. dollars 
WB_searchCode = "NY.GNP.PCAP.CD"

yearSpan = 10      # going back this # of years from latest year
latestYr = 2019    # data available for most recent year

# Initialize lists
WBcountry = []
years = np.arange(latestYr,latestYr-yearSpan,-1)
yearlyData = []
yearlyData_i = []

# For every country with hospital bed data, attempt to retrieve income data
for country in list(total_df["Code"]):

    # Concatenate the query URL
    url = "http://api.worldbank.org/v2/country/"+country+"/indicator/"+WB_searchCode+"?format=json"
    
    # Make JSON request to World Bank API
    bank_data = requests.get(url).json()
    
    # Record data: country id, yearly data for income per capita for ther past yearSpan years
    try:
        WBcountry.append(bank_data[1][0]["countryiso3code"])
        
        for yr in np.arange(0,yearSpan,1):
            yearlyData_i.append(bank_data[1][yr]["value"])
            
        yearlyData.append(yearlyData_i)
        yearlyData_i = []
        
    except:
        print(f"Income data for country {country} not found... skipping.")
# Out:
# Income data for country COK not found... skipping.
# Income data for country NIU not found... skipping.

# %%
# Create data frame with income per capita data
raw_income_df = pd.DataFrame(columns=years, data=yearlyData)
raw_income_df.insert(0, 'Code', WBcountry)

# Set country code as index
raw_income_df = raw_income_df.set_index("Code")

# Record the lastest non-NaN value obtained 
raw_income_df["Latest Data"] = raw_income_df.ffill(axis=1).iloc[:, -1]

# Drop all countries with missing income data
income_data_df = raw_income_df.dropna(subset=["Latest Data"])["Latest Data"]

# Print out a summary of country data obtained
print(f"Only financial data for {len(income_data_df.index)} countries was retrieved from the original {len(total_df.index)}")
# Out:
# Only financial data for 176 countries was retrieved from the original 181

# %% [markdown]
# ----

# %% [markdown]
# ### Merge data into ultimate dataframe

# %%
# Add income data to hospital bed data set
bed_income_data = total_df.merge(income_data_df,left_on="Code",right_on="Code",how="right")

# Rearrange columns for visualization purposes
columns_titles = ["Country","Code","Region","Location","Latest Beds","Latest Data"]
bed_income_data=bed_income_data.reindex(columns=columns_titles)

# Rename columns for better readability
bed_income_data.rename(columns={'Latest Beds':'Hospital Beds','Latest Data':'GNI Per Capita'}, inplace=True)

# Set index to "Country" name
bed_income_data = bed_income_data.set_index("Country")

# Convert GNI per capita into numeric format
bed_income_data["GNI Per Capita"] = pd.to_numeric(bed_income_data["GNI Per Capita"], downcast="float")

bed_income_data.head()
# Out:
#                     Code                 Region        Location  \
# Country
# Afghanistan          AFG  Eastern Mediterranean    [33.0, 65.0]
# Albania              ALB                 Europe    [41.0, 20.0]
# Algeria              DZA                 Africa     [28.0, 3.0]
# Angola               AGO                 Africa   [-12.5, 18.5]
# Antigua and Barbuda  ATG               Americas  [17.05, -61.8]
#
#                      Hospital Beds  GNI Per Capita
# Country
# Afghanistan                    5.0           510.0
# Albania                       29.0          4360.0
# Algeria                       19.0          4480.0
# Angola                         8.0          3240.0
# Antigua and Barbuda           38.0         12690.0

# %%
# Merge COVID-19 data into hospital bed, income per capita data frame
FullData = bed_income_data.merge(CovidPerCountry,left_on="Code",right_on="Code",how="left")

# Provide list of unmatched countries
unfoundCountries2 = FullData.loc[pd.isnull(FullData["CumCase"])]
print(f"List of unmatched coutries:\n{unfoundCountries2['Code']}")
print("\x1b[1;31m"+"OK - These countries do not have COVID-19 data available"+'\x1b[0m')
# Out:
# List of unmatched coutries:
# 86     KIR
# 92     LSO
# 112    NRU
# 146    SLB
# 161    TKM
# 162    TUV
# Name: Code, dtype: object
# OK - These countries do not have COVID-19 data available

# %%
# Remove countries without COVID-19 data and reset_index
FullData2 = FullData.dropna()

FullData2
# Out:
#     Code                 Region                     Location  Hospital Beds  \
# 0    AFG  Eastern Mediterranean                 [33.0, 65.0]            5.0
# 1    ALB                 Europe                 [41.0, 20.0]           29.0
# 2    DZA                 Africa                  [28.0, 3.0]           19.0
# 3    AGO                 Africa                [-12.5, 18.5]            8.0
# 4    ATG               Americas               [17.05, -61.8]           38.0
# ..   ...                    ...                          ...            ...
# 171  VEN               Americas                 [8.0, -66.0]            8.0
# 172  VNM        Western Pacific  [16.16666666, 107.83333333]           26.0
# 173  YEM  Eastern Mediterranean                 [15.0, 48.0]            7.0
# 174  ZMB                 Africa                [-15.0, 30.0]           20.0
# 175  ZWE                 Africa                [-20.0, 30.0]           17.0
#
#      GNI Per Capita  CumCase  CumDeath
# 0             510.0   3224.0      95.0
# 1            4360.0    803.0      31.0
# 2            4480.0   4648.0     465.0
# 3            3240.0     35.0       2.0
# 4           12690.0     25.0       3.0
# ..              ...      ...       ...
# 171         11810.0    357.0      10.0
# 172          1250.0    271.0       0.0
# 173          1200.0     21.0       3.0
# 174          1340.0    137.0       3.0
# 175           630.0     34.0       4.0
#
# [170 rows x 7 columns]

# %%
# Merge health expenditure data to summary data frame
master= FullData2.merge(health_expfull,left_on="Code",right_on="Code", how="left")

# Drop repeated column data and set country name as index
master=master.drop(columns=["Region_y"]).set_index("Country")

master.head()
# Out:
#                     Code               Region_x        Location  \
# Country
# Afghanistan          AFG  Eastern Mediterranean    [33.0, 65.0]
# Albania              ALB                 Europe    [41.0, 20.0]
# Algeria              DZA                 Africa     [28.0, 3.0]
# Angola               AGO                 Africa   [-12.5, 18.5]
# Antigua and Barbuda  ATG               Americas  [17.05, -61.8]
#
#                      Hospital Beds  GNI Per Capita  CumCase  CumDeath  \
# Country
# Afghanistan                    5.0           510.0   3224.0      95.0
# Albania                       29.0          4360.0    803.0      31.0
# Algeria                       19.0          4480.0   4648.0     465.0
# Angola                         8.0          3240.0     35.0       2.0
# Antigua and Barbuda           38.0         12690.0     25.0       3.0
#
#                              IncomeGroup  \
# Country
# Afghanistan                   Low income
# Albania              Upper middle income
# Algeria              Upper middle income
# Angola               Lower middle income
# Antigua and Barbuda          High income
#
#                      Health Expenditure per capita (current USD)  \
# Country
# Afghanistan                                            67.122650
# Albania                                                      NaN
# Algeria                                               258.494293
# Angola                                                114.459641
# Antigua and Barbuda                                   673.859680
#
#                      Health Expenditure (% of GDP)
# Country
# Afghanistan                              11.777194
# Albania                                        NaN
# Algeria                                   6.374322
# Angola                                    2.791500
# Antigua and Barbuda                       4.533532

# %%
# Provide list of unmatched countries
unfoundCountries3 = master.loc[pd.isnull(master["IncomeGroup"])]
print(f"List of unmatched coutries:\n{unfoundCountries3.index}")
# Out:
# List of unmatched coutries:
# Index([], dtype='object', name='Country')

# %% [markdown]
# ----

# %% [markdown]
# ### Export Master Dataframe

# %%
master.to_csv(os.path.join(".","outputs/Master COVID Research.csv"))
